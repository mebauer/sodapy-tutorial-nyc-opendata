# %% [markdown]
# # Socrata API Basics
# ## Socrata Open Data API (SODA) Tutorial Using NYC Open Data
# Author: Mark Bauer

# %% [markdown]
# Table of Contents
# =================
#
#    1. Introduction
#    2. Sodapy
#        - 2.1 Using Sodapy
#    3. Importing Libraries
#    4. Sodapy Socrata Class
#    5. Socrata APIs
#        - 5.1 Socrata API
#        - 5.2 Discovery API
#        - 5.3 Metadata API

# %% [markdown]
# # 1. Introduction
# This notebook demonstrates how to interact with the [Socrata Open Data API (SODA)](https://dev.socrata.com/) using the [sodapy](https://github.com/xmunoz/sodapy) Python client and explores different methods for retrieving data from Socrata-based open data portals. Not only will we learn how to fetch data, but we'll also explore Socrata's available metadata using the [Metadata](https://dev.socrata.com/docs/other/metadata#?route=overview) and [Discovery](https://dev.socrata.com/docs/other/discovery#?route=overview) APIs. For this tutorial, we will use data from NYC Open Data as an example.
#
# While the main focus is on understanding how to interact with the Socrata API, we'll use the sodapy library throughout the examples, as it provides a straightforward interface for working with Socrata. Both the raw Socrata API URLs and sodapy code snippets will be provided to give you flexibility in how you approach your data retrieval.

# %% [markdown]
# # 2. Sodapy
#
# ## 2.1 Using Sodapy
#
# Sodapy is a python client for the Socrata API. In order use sodapy, a source domain (i.e. the Socrata Open Data source you are trying to connect to) needs to be passed to the Socrata class. Additionally, if a user wants to query a specific dataset on Socrata Open Data, then the dataset identifier (i.e. the dataset id on the given source domain) needs to be passed as well. Below, we identify NYC Open Data's source domain: `data.cityofnewyork.us` and the dataset identifier for the NYC 311 dataset: `erm2-nwe9`. The screenshot below displays where we retrieve this information.
#
# This is my preferred method for extracting data from NYC Open Data. However, please note that the Sodapy project is now archived on GitHub.
#
# ![nyc-311-api-docs](images/nyc-311-api-docs.png)
#
# **Source**: https://dev.socrata.com/foundry/data.cityofnewyork.us/erm2-nwe9

# %% [markdown]
# We will be focus on three sodapy methods:
# - `.get()`
# Read data from the requested resource.
#
# -  `.datasets()`
# Returns the list of datasets associated with a particular domain.
#
# - `.get_metadata()`
# Retrieve the metadata for a particular dataset.
#
# For a comprehensive list of all available APIs provided by Socrata, check out the [Other APIs](https://dev.socrata.com/docs/other/) page in the documentation.

# %% [markdown]
# # 3. Importing Libraries

# %%
# importing libraries
import pandas as pd
from sodapy import Socrata
import requests

# %%
# documention for installing watermark: https://github.com/rasbt/watermark
# performed for reproducibility
# %reload_ext watermark
# %watermark -u -t -d -v -p pandas,sodapy
# Out:
# Last updated: 2024-11-30 19:49:05
#
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # 4. Sodapy Socrata Class

# %% [markdown]
# Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# To avoid these limits, it's recommended to use an app token when making API requests.

# %%
## implementation in sodapy
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# Socrata(): The main class that interacts with the SODA API.

# The required arguments are:
#     domain: the domain you wish you to access
#     app_token: your Socrata application token
# Simple requests are possible without an app_token, though these
# requests will be rate-limited.

client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x1102c3650>

# %%
# print information about the Socrata object
print(f'type: {type(client)}')
# Out:
# type: <class 'sodapy.socrata.Socrata'>

# %%
# print attributes of object
for key, value in client.__dict__.items():
    print(f'{key}: {value}')
# Out:
# domain: data.cityofnewyork.us
# session: <requests.sessions.Session object at 0x10cd9c0d0>
# uri_prefix: https://
# timeout: 100

# %% [markdown]
# # 5. Socrata APIs

# %% [markdown]
# ##  5.1 Socrata Open Data API
# [Socrata's Open Data API](https://dev.socrata.com/docs/endpoints).
#
# From [the docs](https://dev.socrata.com/docs/endpoints):
# >The “endpoint” of a SODA API is simply a unique URL that represents an object or collection of objects. Every Socrata dataset, and even every individual data record, has its own endpoint. The endpoint is what you’ll point your HTTP client at to interact with data resources.
# >
# >All resources are accessed through a common base path of /resource/ along with their dataset identifier.

# %% [markdown]
# Sodapy `.get()` method: Read data from the requested resource. Options for content_type are JSON,
# CSV, and XML.
#
# This method performs a get request on these type of URLs: https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=5.

# %% [markdown]
# ### Using Socrata API URL

# %%
# limit 311 dataset to 5 rows
url = 'https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=5'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#    unique_key             created_date agency  \
# 0    63231133  2024-11-29T04:00:33.000    DOT
# 1    63233902  2024-11-29T01:51:28.000   NYPD
# 2    63231561  2024-11-29T01:51:03.000    DPR
# 3    63232135  2024-11-29T01:50:50.000   NYPD
# 4    63233043  2024-11-29T01:50:14.000   NYPD
#
#                           agency_name       complaint_type  \
# 0        Department of Transportation     Street Condition
# 1     New York City Police Department  Noise - Residential
# 2  Department of Parks and Recreation  Illegal Tree Damage
# 3     New York City Police Department  Noise - Residential
# 4     New York City Police Department  Noise - Residential
#
#                 descriptor  incident_zip intersection_street_1  \
# 0                  Pothole       11213.0         ALBANY AVENUE
# 1         Loud Music/Party           NaN                   NaN
# 2  Bicycle Chained to Tree           NaN                   NaN
# 3         Loud Music/Party           NaN                   NaN
# 4         Loud Music/Party           NaN                   NaN
#
#   intersection_street_2  address_type  ...   latitude  longitude  \
# 0          CROWN STREET  INTERSECTION  ...  40.665687 -73.939760
# 1                   NaN           NaN  ...  40.892051 -73.860009
# 2                   NaN           NaN  ...  40.831950 -73.929394
# 3                   NaN           NaN  ...  40.892051 -73.860009
# 4                   NaN           NaN  ...  40.734143 -73.774759
#
#                                             location  \
# 0  {'latitude': '40.66568740802441', 'longitude':...
# 1  {'latitude': '40.89205062779512', 'longitude':...
# 2  {'latitude': '40.83195011687482', 'longitude':...
# 3  {'latitude': '40.89205062779512', 'longitude':...
# 4  {'latitude': '40.73414322554409', 'longitude':...
#
#   :@computed_region_efsh_h5xi :@computed_region_f5dn_yrer  \
# 0                       17615                          17
# 1                       11275                          29
# 2                       10930                          50
# 3                       11275                          29
# 4                       14508                          25
#
#   :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                           2                          48
# 1                           5                           2
# 2                           5                          35
# 3                           5                           2
# 4                           3                          16
#
#    :@computed_region_sbqj_enih  :@computed_region_7mpf_4k6g  \
# 0                           44                           44
# 1                           30                           30
# 2                           27                           27
# 3                           30                           30
# 4                           65                           65
#
#                 location_type
# 0                         NaN
# 1  Residential Building/House
# 2                      Street
# 3  Residential Building/House
# 4  Residential Building/House
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# NYC 311 dataset identifier
socrata_dataset_identifier = 'erm2-nwe9'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=1000
)

# get data for the 311 dataset, limit to 5 rows
# notice the limit parameter
data = client.get(socrata_dataset_identifier, limit=5)

# identify type of object returned
print(type(data))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <class 'list'>

# %%
# preview first element in list
data[0]
# Out:
# {'unique_key': '63231133',
#  'created_date': '2024-11-29T04:00:33.000',
#  'agency': 'DOT',
#  'agency_name': 'Department of Transportation',
#  'complaint_type': 'Street Condition',
#  'descriptor': 'Pothole',
#  'incident_zip': '11213',
#  'intersection_street_1': 'ALBANY AVENUE',
#  'intersection_street_2': 'CROWN STREET',
#  'address_type': 'INTERSECTION',
#  'city': 'BROOKLYN',
#  'facility_type': 'N/A',
#  'status': 'Open',
#  'resolution_description': 'The Department of Transportation referred this complaint to the appropriate Maintenance Unit for repair.',
#  'resolution_action_updated_date': '2024-11-29T04:00:33.000',
#  'community_board': '09 BROOKLYN',
#  'borough': 'BROOKLYN',
#  'x_coordinate_state_plane': '1000962',
#  'y_coordinate_state_plane': '181810',
#  'open_data_channel_type': 'UNKNOWN',
#  'park_facility_name': 'Unspecified',
#  'park_borough': 'BROOKLYN',
#  'latitude': '40.66568740802441',
#  'longitude': '-73.93975997355022',
#  'location': {'latitude': '40.66568740802441',
#   'longitude': '-73.93975997355022',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#  ':@computed_region_efsh_h5xi': '17615',
#  ':@computed_region_f5dn_yrer': '17',
#  ':@computed_region_yeji_bk3q': '2',
#  ':@computed_region_92fq_4b7q': '48',
#  ':@computed_region_sbqj_enih': '44',
#  ':@computed_region_7mpf_4k6g': '44'}

# %%
# convert list to a df
df = pd.DataFrame(data)

# sanity check
print(df.shape)
df.head()
# Out:
# (5, 32)
#   unique_key             created_date agency  \
# 0   63231133  2024-11-29T04:00:33.000    DOT
# 1   63233902  2024-11-29T01:51:28.000   NYPD
# 2   63231561  2024-11-29T01:51:03.000    DPR
# 3   63232135  2024-11-29T01:50:50.000   NYPD
# 4   63233043  2024-11-29T01:50:14.000   NYPD
#
#                           agency_name       complaint_type  \
# 0        Department of Transportation     Street Condition
# 1     New York City Police Department  Noise - Residential
# 2  Department of Parks and Recreation  Illegal Tree Damage
# 3     New York City Police Department  Noise - Residential
# 4     New York City Police Department  Noise - Residential
#
#                 descriptor incident_zip intersection_street_1  \
# 0                  Pothole        11213         ALBANY AVENUE
# 1         Loud Music/Party          NaN                   NaN
# 2  Bicycle Chained to Tree          NaN                   NaN
# 3         Loud Music/Party          NaN                   NaN
# 4         Loud Music/Party          NaN                   NaN
#
#   intersection_street_2  address_type  ...           latitude  \
# 0          CROWN STREET  INTERSECTION  ...  40.66568740802441
# 1                   NaN           NaN  ...  40.89205062779512
# 2                   NaN           NaN  ...  40.83195011687482
# 3                   NaN           NaN  ...  40.89205062779512
# 4                   NaN           NaN  ...  40.73414322554409
#
#             longitude                                           location  \
# 0  -73.93975997355022  {'latitude': '40.66568740802441', 'longitude':...
# 1  -73.86000893554395  {'latitude': '40.89205062779512', 'longitude':...
# 2  -73.92939377993235  {'latitude': '40.83195011687482', 'longitude':...
# 3  -73.86000893554395  {'latitude': '40.89205062779512', 'longitude':...
# 4   -73.7747588426775  {'latitude': '40.73414322554409', 'longitude':...
#
#   :@computed_region_efsh_h5xi :@computed_region_f5dn_yrer  \
# 0                       17615                          17
# 1                       11275                          29
# 2                       10930                          50
# 3                       11275                          29
# 4                       14508                          25
#
#   :@computed_region_yeji_bk3q :@computed_region_92fq_4b7q  \
# 0                           2                          48
# 1                           5                           2
# 2                           5                          35
# 3                           5                           2
# 4                           3                          16
#
#   :@computed_region_sbqj_enih :@computed_region_7mpf_4k6g  \
# 0                          44                          44
# 1                          30                          30
# 2                          27                          27
# 3                          30                          30
# 4                          65                          65
#
#                 location_type
# 0                         NaN
# 1  Residential Building/House
# 2                      Street
# 3  Residential Building/House
# 4  Residential Building/House
#
# [5 rows x 32 columns]

# %% [markdown]
# Example with the QUERY parameter.

# %%
## SoQL implementation with sodapy
# SoQL query string below:
# retrieve all columns and limit our records to 100

query = """
    SELECT *
    LIMIT 100
"""

# returned as JSON from API / converted to Python list of dictionaries by sodapy
# notice the query parameter
results = client.get(socrata_dataset_identifier, query=query)

# convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# sanity check
print(f'shape of data: {results_df.shape}')
results_df.head()
# Out:
# shape of data: (100, 43)
#   unique_key             created_date agency  \
# 0   63231133  2024-11-29T04:00:33.000    DOT
# 1   63233902  2024-11-29T01:51:28.000   NYPD
# 2   63231561  2024-11-29T01:51:03.000    DPR
# 3   63232135  2024-11-29T01:50:50.000   NYPD
# 4   63233043  2024-11-29T01:50:14.000   NYPD
#
#                           agency_name       complaint_type  \
# 0        Department of Transportation     Street Condition
# 1     New York City Police Department  Noise - Residential
# 2  Department of Parks and Recreation  Illegal Tree Damage
# 3     New York City Police Department  Noise - Residential
# 4     New York City Police Department  Noise - Residential
#
#                 descriptor incident_zip intersection_street_1  \
# 0                  Pothole        11213         ALBANY AVENUE
# 1         Loud Music/Party          NaN                   NaN
# 2  Bicycle Chained to Tree          NaN                   NaN
# 3         Loud Music/Party          NaN                   NaN
# 4         Loud Music/Party          NaN                   NaN
#
#   intersection_street_2  address_type  ... bridge_highway_direction  \
# 0          CROWN STREET  INTERSECTION  ...                      NaN
# 1                   NaN           NaN  ...                      NaN
# 2                   NaN           NaN  ...                      NaN
# 3                   NaN           NaN  ...                      NaN
# 4                   NaN           NaN  ...                      NaN
#
#   bridge_highway_segment vehicle_type incident_address street_name  \
# 0                    NaN          NaN              NaN         NaN
# 1                    NaN          NaN              NaN         NaN
# 2                    NaN          NaN              NaN         NaN
# 3                    NaN          NaN              NaN         NaN
# 4                    NaN          NaN              NaN         NaN
#
#   cross_street_1 cross_street_2 landmark  bbl closed_date
# 0            NaN            NaN      NaN  NaN         NaN
# 1            NaN            NaN      NaN  NaN         NaN
# 2            NaN            NaN      NaN  NaN         NaN
# 3            NaN            NaN      NaN  NaN         NaN
# 4            NaN            NaN      NaN  NaN         NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ## 5.2  Discovery API
# Socrata's [Discovery API](https://dev.socrata.com/docs/other/discovery#?route=overview).

# %% [markdown]
# Sodapy `.datasets()` method: Returns the list of datasets associated with a particular domain.
# WARNING: Large limits (>1000) will return megabytes of data,
# which can be slow on low-bandwidth networks, and is also a lot of
# data to hold in memory.
#
# This method performs a get request on these type of URLs: https://data.cityofnewyork.us/api/catalog/v1.

# %% [markdown]
# ### Using Socrata API URL

# %%
# discovery api
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.ny.gov'

# Fetch the JSON data from the web
response = requests.get(url)

# Parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# preview results key, first element
data_dict['results'][0]
# Out:
# {'resource': {'name': 'Lottery Cash 4 Life Winning Numbers: Beginning 2014',
#   'id': 'kwxv-fwze',
#   'resource_name': None,
#   'parent_fxf': [],
#   'description': 'Go to http://on.ny.gov/1xRIvPz on the New York Lottery website for past Cash 4 Life results and payouts.',
#   'attribution': 'New York State Gaming Commission',
#   'attribution_link': 'http://nylottery.ny.gov/wps/portal/Home/Lottery/home/your+lottery/drawing+results/drawingresults_cash4life',
#   'contact_email': 'opendata@its.ny.gov',
#   'type': 'dataset',
#   'updatedAt': '2024-11-30T11:03:52.000Z',
#   'createdAt': '2014-06-17T19:47:54.000Z',
#   'metadata_updated_at': '2024-11-30T11:03:51.000Z',
#   'data_updated_at': '2024-11-30T11:03:52.000Z',
#   'page_views': {'page_views_last_week': 426,
#    'page_views_last_month': 2664,
#    'page_views_total': 5932662,
#    'page_views_last_week_log': 8.73809225962049,
#    'page_views_last_month_log': 11.379919817646538,
#    'page_views_total_log': 22.500248403354632},
#   'columns_name': ['Winning Numbers', 'Cash Ball', 'Draw Date'],
#   'columns_field_name': ['winning_numbers', 'cash_ball', 'draw_date'],
#   'columns_datatype': ['Text', 'Text', 'Calendar date'],
#   'columns_description': ['Winning numbers', 'Cash ball', 'Draw date'],
#   'columns_format': [{'align': 'center'},
#    {'align': 'center'},
#    {'view': 'date', 'align': 'center'}],
#   'download_count': 230669,
#   'provenance': 'official',
#   'lens_view_type': 'tabular',
#   'lens_display_type': 'table',
#   'locked': False,
#   'blob_mime_type': None,
#   'hide_from_data_json': False,
#   'publication_date': '2021-04-27T14:13:45.000Z'},
#  'classification': {'categories': [],
#   'tags': [],
#   'domain_category': 'Government & Finance',
#   'domain_tags': ['cash 4 life', 'new york lottery', 'results', 'winning'],
#   'domain_metadata': [{'key': 'Common-Core_Publisher',
#     'value': 'State of New York'},
#    {'key': 'Common-Core_Contact-Name', 'value': 'Open Data NY'},
#    {'key': 'Common-Core_Contact-Email', 'value': 'opendata@its.ny.gov'},
#    {'key': 'Additional-Resources_See-Also',
#     'value': 'http://www.gaming.ny.gov/'},
#    {'key': 'Dataset-Summary_Dataset-Owner',
#     'value': 'New York State Gaming Commission'},
#    {'key': 'Dataset-Summary_Contact-Information',
#     'value': 'Info@gaming.ny.gov'},
#    {'key': 'Dataset-Summary_Granularity', 'value': 'By draw'},
#    {'key': 'Dataset-Summary_Coverage', 'value': 'Statewide'},
#    {'key': 'Dataset-Summary_Data-Frequency',
#     'value': 'Daily beginning 7/1/19; twice weekly previously'},
#    {'key': 'Dataset-Summary_Posting-Frequency', 'value': 'Daily'},
#    {'key': 'Dataset-Summary_Organization', 'value': 'The New York Lottery'},
#    {'key': 'Dataset-Summary_Time-Period', 'value': 'Beginning 6/16/2014'},
#    {'key': 'Dataset-Information_Agency',
#     'value': 'Gaming Commission, New York State'},
#    {'key': 'Notes_Notes',
#     'value': "The information contained on these pages is believed to be accurate. In the event of a discrepancy between the information displayed on this Web site concerning winning numbers and payouts and the information contained in the official and certified files maintained by the New York Lottery's Drawing Unit, those maintained by the Drawing Unit shall prevail."}]},
#  'metadata': {'domain': 'data.ny.gov'},
#  'permalink': 'https://data.ny.gov/d/kwxv-fwze',
#  'link': 'https://data.ny.gov/Government-Finance/Lottery-Cash-4-Life-Winning-Numbers-Beginning-2014/kwxv-fwze',
#  'owner': {'id': 'xzik-pf59',
#   'user_type': 'interactive',
#   'display_name': 'NY Open Data'},
#  'creator': {'id': 'xzik-pf59',
#   'user_type': 'interactive',
#   'display_name': 'NY Open Data'}}

# %%
# convert into df
df = pd.DataFrame(data_dict['results'])

# sanity check
print(df.shape)
df.head()
# Out:
# (100, 8)
#                                             resource  \
# 0  {'name': 'Lottery Cash 4 Life Winning Numbers:...
# 1  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 2  {'name': 'Civil Service List (Active)', 'id': ...
# 3  {'name': 'DOB Job Application Filings', 'id': ...
# 4  {'name': 'Medicaid Enrolled Provider Listing',...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0            {'domain': 'data.ny.gov'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4     {'domain': 'health.data.ny.gov'}
#
#                                    permalink  \
# 0            https://data.ny.gov/d/kwxv-fwze
# 1  https://data.cityofnewyork.us/d/8wbx-tsch
# 2  https://data.cityofnewyork.us/d/vx8i-nprf
# 3  https://data.cityofnewyork.us/d/ic3t-wcy2
# 4     https://health.data.ny.gov/d/keti-qx5t
#
#                                                 link  \
# 0  https://data.ny.gov/Government-Finance/Lottery...
# 1  https://data.cityofnewyork.us/Transportation/F...
# 2  https://data.cityofnewyork.us/City-Government/...
# 3  https://data.cityofnewyork.us/Housing-Developm...
# 4  https://health.data.ny.gov/Health/Medicaid-Enr...
#
#                                                owner  \
# 0  {'id': 'xzik-pf59', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': 's9j2-nqmr', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': 'xzik-pf59', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': 's9j2-nqmr', 'user_type': 'interactive'...               NaN

# %% [markdown]
# This is not our final dataframe. Our information most likely is located in the resource column, but let's confirm.

# %% [markdown]
# Briefly review the other keys.

# %%
# first element in our results list, preview resources key
data_dict['results'][0]['resource']
# Out:
# {'name': 'Lottery Cash 4 Life Winning Numbers: Beginning 2014',
#  'id': 'kwxv-fwze',
#  'resource_name': None,
#  'parent_fxf': [],
#  'description': 'Go to http://on.ny.gov/1xRIvPz on the New York Lottery website for past Cash 4 Life results and payouts.',
#  'attribution': 'New York State Gaming Commission',
#  'attribution_link': 'http://nylottery.ny.gov/wps/portal/Home/Lottery/home/your+lottery/drawing+results/drawingresults_cash4life',
#  'contact_email': 'opendata@its.ny.gov',
#  'type': 'dataset',
#  'updatedAt': '2024-11-30T11:03:52.000Z',
#  'createdAt': '2014-06-17T19:47:54.000Z',
#  'metadata_updated_at': '2024-11-30T11:03:51.000Z',
#  'data_updated_at': '2024-11-30T11:03:52.000Z',
#  'page_views': {'page_views_last_week': 426,
#   'page_views_last_month': 2664,
#   'page_views_total': 5932662,
#   'page_views_last_week_log': 8.73809225962049,
#   'page_views_last_month_log': 11.379919817646538,
#   'page_views_total_log': 22.500248403354632},
#  'columns_name': ['Winning Numbers', 'Cash Ball', 'Draw Date'],
#  'columns_field_name': ['winning_numbers', 'cash_ball', 'draw_date'],
#  'columns_datatype': ['Text', 'Text', 'Calendar date'],
#  'columns_description': ['Winning numbers', 'Cash ball', 'Draw date'],
#  'columns_format': [{'align': 'center'},
#   {'align': 'center'},
#   {'view': 'date', 'align': 'center'}],
#  'download_count': 230669,
#  'provenance': 'official',
#  'lens_view_type': 'tabular',
#  'lens_display_type': 'table',
#  'locked': False,
#  'blob_mime_type': None,
#  'hide_from_data_json': False,
#  'publication_date': '2021-04-27T14:13:45.000Z'}

# %%
# first element in our results list, preview classification key
data_dict['results'][0]['classification']
# Out:
# {'categories': [],
#  'tags': [],
#  'domain_category': 'Government & Finance',
#  'domain_tags': ['cash 4 life', 'new york lottery', 'results', 'winning'],
#  'domain_metadata': [{'key': 'Common-Core_Publisher',
#    'value': 'State of New York'},
#   {'key': 'Common-Core_Contact-Name', 'value': 'Open Data NY'},
#   {'key': 'Common-Core_Contact-Email', 'value': 'opendata@its.ny.gov'},
#   {'key': 'Additional-Resources_See-Also',
#    'value': 'http://www.gaming.ny.gov/'},
#   {'key': 'Dataset-Summary_Dataset-Owner',
#    'value': 'New York State Gaming Commission'},
#   {'key': 'Dataset-Summary_Contact-Information',
#    'value': 'Info@gaming.ny.gov'},
#   {'key': 'Dataset-Summary_Granularity', 'value': 'By draw'},
#   {'key': 'Dataset-Summary_Coverage', 'value': 'Statewide'},
#   {'key': 'Dataset-Summary_Data-Frequency',
#    'value': 'Daily beginning 7/1/19; twice weekly previously'},
#   {'key': 'Dataset-Summary_Posting-Frequency', 'value': 'Daily'},
#   {'key': 'Dataset-Summary_Organization', 'value': 'The New York Lottery'},
#   {'key': 'Dataset-Summary_Time-Period', 'value': 'Beginning 6/16/2014'},
#   {'key': 'Dataset-Information_Agency',
#    'value': 'Gaming Commission, New York State'},
#   {'key': 'Notes_Notes',
#    'value': "The information contained on these pages is believed to be accurate. In the event of a discrepancy between the information displayed on this Web site concerning winning numbers and payouts and the information contained in the official and certified files maintained by the New York Lottery's Drawing Unit, those maintained by the Drawing Unit shall prevail."}]}

# %%
# first element in our results list, preview metadata key
data_dict['results'][0]['metadata']
# Out:
# {'domain': 'data.ny.gov'}

# %%
# first element in our results list, preview permalink key
data_dict['results'][0]['permalink']
# Out:
# 'https://data.ny.gov/d/kwxv-fwze'

# %%
# first element in our results list, preview link key
data_dict['results'][0]['link']
# Out:
# 'https://data.ny.gov/Government-Finance/Lottery-Cash-4-Life-Winning-Numbers-Beginning-2014/kwxv-fwze'

# %%
# first element in our results list, preview owner key
data_dict['results'][0]['owner']
# Out:
# {'id': 'xzik-pf59', 'user_type': 'interactive', 'display_name': 'NY Open Data'}

# %%
# first element in our results list, preview creator key
data_dict['results'][0]['creator']
# Out:
# {'id': 'xzik-pf59', 'user_type': 'interactive', 'display_name': 'NY Open Data'}

# %%
# retrieve information in the resource key
# switch back to our dataframe object
df['resource']
# Out:
# 0     {'name': 'Lottery Cash 4 Life Winning Numbers:...
# 1     {'name': 'For Hire Vehicles (FHV) - Active', '...
# 2     {'name': 'Civil Service List (Active)', 'id': ...
# 3     {'name': 'DOB Job Application Filings', 'id': ...
# 4     {'name': 'Medicaid Enrolled Provider Listing',...
#                             ...
# 95    {'name': 'Lottery Pick 10 Winning Numbers: Beg...
# 96    {'name': 'Street Hail Livery (SHL) Permits', '...
# 97    {'name': 'NYPD Complaint Data Current (Year To...
# 98    {'name': 'Index Crimes by County and Agency: B...
# 99    {'name': 'TLC Approved LabCorp Patient Service...
# Name: resource, Length: 100, dtype: object

# %%
# normalize JSON
df = pd.json_normalize(df['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (100, 32)
#                                                 name         id resource_name  \
# 0  Lottery Cash 4 Life Winning Numbers: Beginning...  kwxv-fwze          None
# 1                   For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 2                        Civil Service List (Active)  vx8i-nprf          None
# 3                        DOB Job Application Filings  ic3t-wcy2          None
# 4                 Medicaid Enrolled Provider Listing  keti-qx5t          None
#
#   parent_fxf                                        description  \
# 0         []  Go to http://on.ny.gov/1xRIvPz on the New York...
# 1         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 2         []  A Civil Service List consists of all candidate...
# 3         []  This dataset contains all job applications sub...
# 4         []  <b>Revalidation disclaimer</b>:  The next anti...
#
#                                          attribution  \
# 0                   New York State Gaming Commission
# 1                Taxi and Limousine Commission (TLC)
# 2  Department of Citywide Administrative Services...
# 3                      Department of Buildings (DOB)
# 4                New York State Department of Health
#
#                                     attribution_link        contact_email  \
# 0  http://nylottery.ny.gov/wps/portal/Home/Lotter...  opendata@its.ny.gov
# 1                                               None                 None
# 2                                               None                 None
# 3                                               None                 None
# 4  https://www.emedny.org/info/ProviderEnrollment...                 None
#
#       type                 updatedAt  ... locked blob_mime_type  \
# 0  dataset  2024-11-30T11:03:52.000Z  ...  False           None
# 1  dataset  2024-11-30T20:05:48.000Z  ...  False           None
# 2  dataset  2024-11-29T14:20:44.000Z  ...  False           None
# 3  dataset  2024-11-30T21:06:12.000Z  ...  False           None
# 4  dataset  2024-11-25T19:21:50.000Z  ...  False           None
#
#   hide_from_data_json          publication_date  \
# 0               False  2021-04-27T14:13:45.000Z
# 1               False  2021-04-05T13:20:47.000Z
# 2               False  2024-01-12T16:15:05.000Z
# 3               False  2020-06-22T18:23:35.000Z
# 4               False  2020-12-28T16:03:15.000Z
#
#   page_views.page_views_last_week page_views.page_views_last_month  \
# 0                             426                             2664
# 1                               1                               12
# 2                               0                                0
# 3                               2                               14
# 4                               0                                0
#
#   page_views.page_views_total page_views.page_views_last_week_log  \
# 0                     5932662                            8.738092
# 1                         186                            1.000000
# 2                           0                                 NaN
# 3                          79                            1.584963
# 4                           0                                 NaN
#
#    page_views.page_views_last_month_log page_views.page_views_total_log
# 0                             11.379920                       22.500248
# 1                              3.700440                        7.546894
# 2                                   NaN                             NaN
# 3                              3.906891                        6.321928
# 4                                   NaN                             NaN
#
# [5 rows x 32 columns]

# %%
# inspect available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   name                                  100 non-null    object
#  1   id                                    100 non-null    object
#  2   resource_name                         1 non-null      object
#  3   parent_fxf                            100 non-null    object
#  4   description                           100 non-null    object
#  5   attribution                           89 non-null     object
#  6   attribution_link                      51 non-null     object
#  7   contact_email                         20 non-null     object
#  8   type                                  100 non-null    object
#  9   updatedAt                             100 non-null    object
#  10  createdAt                             100 non-null    object
#  11  metadata_updated_at                   100 non-null    object
#  12  data_updated_at                       100 non-null    object
#  13  columns_name                          100 non-null    object
#  14  columns_field_name                    100 non-null    object
#  15  columns_datatype                      100 non-null    object
#  16  columns_description                   100 non-null    object
#  17  columns_format                        100 non-null    object
#  18  download_count                        100 non-null    int64
#  19  provenance                            100 non-null    object
#  20  lens_view_type                        100 non-null    object
#  21  lens_display_type                     100 non-null    object
#  22  locked                                100 non-null    bool
#  23  blob_mime_type                        3 non-null      object
#  24  hide_from_data_json                   100 non-null    bool
#  25  publication_date                      100 non-null    object
#  26  page_views.page_views_last_week       100 non-null    int64
#  27  page_views.page_views_last_month      100 non-null    int64
#  28  page_views.page_views_total           100 non-null    int64
#  29  page_views.page_views_last_week_log   69 non-null     float64
#  30  page_views.page_views_last_month_log  69 non-null     float64
#  31  page_views.page_views_total_log       69 non-null     float64
# dtypes: bool(2), float64(3), int64(4), object(23)
# memory usage: 23.8+ KB

# %%
# preview columns and values
df.T
# Out:
#                                                                                      0   \
# name                                  Lottery Cash 4 Life Winning Numbers: Beginning...
# id                                                                            kwxv-fwze
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           Go to http://on.ny.gov/1xRIvPz on the New York...
# attribution                                            New York State Gaming Commission
# attribution_link                      http://nylottery.ny.gov/wps/portal/Home/Lotter...
# contact_email                                                       opendata@its.ny.gov
# type                                                                            dataset
# updatedAt                                                      2024-11-30T11:03:52.000Z
# createdAt                                                      2014-06-17T19:47:54.000Z
# metadata_updated_at                                            2024-11-30T11:03:51.000Z
# data_updated_at                                                2024-11-30T11:03:52.000Z
# columns_name                                    [Winning Numbers, Cash Ball, Draw Date]
# columns_field_name                              [winning_numbers, cash_ball, draw_date]
# columns_datatype                                            [Text, Text, Calendar date]
# columns_description                             [Winning numbers, Cash ball, Draw date]
# columns_format                        [{'align': 'center'}, {'align': 'center'}, {'v...
# download_count                                                                   230669
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-04-27T14:13:45.000Z
# page_views.page_views_last_week                                                     426
# page_views.page_views_last_month                                                   2664
# page_views.page_views_total                                                     5932662
# page_views.page_views_last_week_log                                            8.738092
# page_views.page_views_last_month_log                                           11.37992
# page_views.page_views_total_log                                               22.500248
#
#                                                                                      1   \
# name                                                   For Hire Vehicles (FHV) - Active
# id                                                                            8wbx-tsch
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>PLEASE NOTE:</b> This dataset, which includ...
# attribution                                         Taxi and Limousine Commission (TLC)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T20:05:48.000Z
# createdAt                                                      2015-07-16T17:33:32.000Z
# metadata_updated_at                                            2022-09-06T21:05:32.000Z
# data_updated_at                                                2024-11-30T20:05:48.000Z
# columns_name                          [Hack Up Date, Base Address, Order Date, Vehic...
# columns_field_name                    [hack_up_date, base_address, order_date, vehic...
# columns_datatype                      [Calendar date, Text, Calendar date, Number, T...
# columns_description                   [Hack Up Date, Base Address, Date Suspension o...
# columns_format                        [{'view': 'date', 'align': 'left'}, {'displayS...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-04-05T13:20:47.000Z
# page_views.page_views_last_week                                                       1
# page_views.page_views_last_month                                                     12
# page_views.page_views_total                                                         186
# page_views.page_views_last_week_log                                                 1.0
# page_views.page_views_last_month_log                                            3.70044
# page_views.page_views_total_log                                                7.546894
#
#                                                                                      2   \
# name                                                        Civil Service List (Active)
# id                                                                            vx8i-nprf
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           A Civil Service List consists of all candidate...
# attribution                           Department of Citywide Administrative Services...
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-29T14:20:44.000Z
# createdAt                                                      2016-06-14T21:12:15.000Z
# metadata_updated_at                                            2024-05-14T14:26:52.000Z
# data_updated_at                                                2024-11-29T14:20:44.000Z
# columns_name                          [Group No, Extension Date, Established Date, P...
# columns_field_name                    [group_no, extension_date, established_date, p...
# columns_datatype                      [Text, Calendar date, Calendar date, Calendar ...
# columns_description                   [Represents the certification order for a list...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2024-01-12T16:15:05.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      3   \
# name                                                        DOB Job Application Filings
# id                                                                            ic3t-wcy2
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           This dataset contains all job applications sub...
# attribution                                               Department of Buildings (DOB)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T21:06:12.000Z
# createdAt                                                      2013-04-18T15:18:56.000Z
# metadata_updated_at                                            2020-06-23T02:08:44.000Z
# data_updated_at                                                2024-11-30T21:06:12.000Z
# columns_name                          [Owner'sHouse Street Name, Owner's House Numbe...
# columns_field_name                    [owner_shouse_street_name, owner_s_house_numbe...
# columns_datatype                      [Text, Text, Text, Text, Text, Number, Number,...
# columns_description                   [House Street Name of Property Owner, House Nu...
# columns_format                        [{'align': 'right'}, {'align': 'right'}, {'ali...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2020-06-22T18:23:35.000Z
# page_views.page_views_last_week                                                       2
# page_views.page_views_last_month                                                     14
# page_views.page_views_total                                                          79
# page_views.page_views_last_week_log                                            1.584963
# page_views.page_views_last_month_log                                           3.906891
# page_views.page_views_total_log                                                6.321928
#
#                                                                                      4   \
# name                                                 Medicaid Enrolled Provider Listing
# id                                                                            keti-qx5t
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>Revalidation disclaimer</b>:  The next anti...
# attribution                                         New York State Department of Health
# attribution_link                      https://www.emedny.org/info/ProviderEnrollment...
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-25T19:21:50.000Z
# createdAt                                                      2017-06-23T17:09:42.000Z
# metadata_updated_at                                            2024-11-25T19:16:19.000Z
# data_updated_at                                                2024-11-25T19:21:50.000Z
# columns_name                          [LATITUDE, NPI, LONGITUDE, TELEPHONE, STATE, M...
# columns_field_name                    [latitude, npi, longitude, telephone, state, m...
# columns_datatype                      [Text, Text, Text, Text, Text, Text, Text, Tex...
# columns_description                   [Latitude related to the service address for t...
# columns_format                        [{}, {'align': 'right'}, {}, {}, {'align': 'le...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2020-12-28T16:03:15.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      5   \
# name                                                  TLC New Driver Application Status
# id                                                                            dpec-ucu7
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           THIS DATASET IS UPDATED SEVERAL TIMES PER DAY....
# attribution                                         Taxi and Limousine Commission (TLC)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T23:00:27.000Z
# createdAt                                                      2016-05-17T18:43:43.000Z
# metadata_updated_at                                            2022-05-09T22:28:03.000Z
# data_updated_at                                                2024-11-30T23:00:27.000Z
# columns_name                          [App Date, FRU Interview Scheduled, Driver Exa...
# columns_field_name                    [app_date, fru_interview_scheduled, driver_exa...
# columns_datatype                      [Calendar date, Text, Text, Text, Text, Number...
# columns_description                   [The date you submitted your application., Fit...
# columns_format                        [{'view': 'date', 'align': 'left'}, {'displayS...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2019-12-17T18:44:57.000Z
# page_views.page_views_last_week                                                       5
# page_views.page_views_last_month                                                     26
# page_views.page_views_total                                                         365
# page_views.page_views_last_week_log                                            2.584963
# page_views.page_views_last_month_log                                           4.754888
# page_views.page_views_total_log                                                  8.5157
#
#                                                                                      6   \
# name                                  Lottery Daily Numbers/Win-4 Winning Numbers: B...
# id                                                                            hsys-3def
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           Go to http://on.ny.gov/1Cx6zvs or http://on.ny...
# attribution                                            New York State Gaming Commission
# attribution_link                      http://nylottery.ny.gov/wps/portal/Home/Lotter...
# contact_email                                                       opendata@its.ny.gov
# type                                                                            dataset
# updatedAt                                                      2024-11-30T11:03:52.000Z
# createdAt                                                      2013-02-26T20:21:34.000Z
# metadata_updated_at                                            2024-11-30T11:03:50.000Z
# data_updated_at                                                2024-11-30T11:03:52.000Z
# columns_name                          [Midday Win 4 Sum, Midday Daily Sum, Evening D...
# columns_field_name                    [midday_win_4_sum, midday_daily_sum, evening_d...
# columns_datatype                      [Number, Number, Text, Number, Number, Text, T...
# columns_description                   [Midday Win 4 Lucky Sum, Winning Midday Daily ...
# columns_format                        [{'precisionStyle': 'standard', 'noCommas': 'f...
# download_count                                                                    88870
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-04-27T14:48:41.000Z
# page_views.page_views_last_week                                                    2807
# page_views.page_views_last_month                                                  12450
# page_views.page_views_total                                                     1718061
# page_views.page_views_last_week_log                                           11.455327
# page_views.page_views_last_month_log                                          13.603974
# page_views.page_views_total_log                                               20.712351
#
#                                                                                      7   \
# name                                           For Hire Vehicles (FHV) - Active Drivers
# id                                                                            xjfq-wh2d
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>PLEASE NOTE:</b> This dataset, which includ...
# attribution                                         Taxi and Limousine Commission (TLC)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T20:07:19.000Z
# createdAt                                                      2015-07-16T17:24:02.000Z
# metadata_updated_at                                            2024-01-11T19:58:17.000Z
# data_updated_at                                                2024-11-30T20:07:19.000Z
# columns_name                          [License Number, Expiration Date, Last Time Up...
# columns_field_name                    [license_number, expiration_date, last_time_up...
# columns_datatype                      [Number, Calendar date, Text, Text, Text, Cale...
# columns_description                   [FHV License Number\n, Expiration Date\n\n\n, ...
# columns_format                        [{'precisionStyle': 'standard', 'noCommas': 't...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2024-01-11T19:58:17.000Z
# page_views.page_views_last_week                                                       2
# page_views.page_views_last_month                                                      9
# page_views.page_views_total                                                         199
# page_views.page_views_last_week_log                                            1.584963
# page_views.page_views_last_month_log                                           3.321928
# page_views.page_views_total_log                                                7.643856
#
#                                                                                      8   \
# name                                          311 Service Requests from 2010 to Present
# id                                                                            erm2-nwe9
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>NOTE:</b> The 311 dataset is currently show...
# attribution                                                                         311
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T02:32:46.000Z
# createdAt                                                      2011-10-10T05:52:17.000Z
# metadata_updated_at                                            2024-05-28T20:32:16.000Z
# data_updated_at                                                2024-11-30T02:32:46.000Z
# columns_name                          [Bridge Highway Name, Borough, Bridge Highway ...
# columns_field_name                    [bridge_highway_name, borough, bridge_highway_...
# columns_datatype                      [Text, Text, Text, Text, Text, Number, Text, C...
# columns_description                   [If the incident is identified as a Bridge/Hig...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2023-12-01T06:51:46.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 0.0
# page_views.page_views_last_month_log                                                0.0
# page_views.page_views_total_log                                                     0.0
#
#                                                                                      9   \
# name                                                   Civil Service List Certification
# id                                                                            a9md-ynri
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           A List Certification includes the names of eli...
# attribution                           Department of Citywide Administrative Services...
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-28T14:06:09.000Z
# createdAt                                                      2016-11-16T19:24:56.000Z
# metadata_updated_at                                            2024-05-14T14:29:26.000Z
# data_updated_at                                                2024-11-28T14:06:09.000Z
# columns_name                          [List Agency Code, List Agency Desc, First Nam...
# columns_field_name                    [list_agency_code, list_agency_desc, first_nam...
# columns_datatype                      [Text, Text, Text, Number, Text, Number, Numbe...
# columns_description                   [A three (3) digit number used to identify an ...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-04-22T15:38:30.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                       ...  \
# name                                  ...
# id                                    ...
# resource_name                         ...
# parent_fxf                            ...
# description                           ...
# attribution                           ...
# attribution_link                      ...
# contact_email                         ...
# type                                  ...
# updatedAt                             ...
# createdAt                             ...
# metadata_updated_at                   ...
# data_updated_at                       ...
# columns_name                          ...
# columns_field_name                    ...
# columns_datatype                      ...
# columns_description                   ...
# columns_format                        ...
# download_count                        ...
# provenance                            ...
# lens_view_type                        ...
# lens_display_type                     ...
# locked                                ...
# blob_mime_type                        ...
# hide_from_data_json                   ...
# publication_date                      ...
# page_views.page_views_last_week       ...
# page_views.page_views_last_month      ...
# page_views.page_views_total           ...
# page_views.page_views_last_week_log   ...
# page_views.page_views_last_month_log  ...
# page_views.page_views_total_log       ...
#
#                                                                                      90  \
# name                                                 Farmers' Markets in New York State
# id                                                                            qq4h-8p86
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           In the past decade the number of farmers' mark...
# attribution                           New York State Department of Agriculture and M...
# attribution_link                      http://www.agriculture.ny.gov/AP/CommunityFarm...
# contact_email                                                       opendata@its.ny.gov
# type                                                                            dataset
# updatedAt                                                      2024-11-15T21:55:17.000Z
# createdAt                                                      2013-04-10T13:48:44.000Z
# metadata_updated_at                                            2024-11-15T21:55:16.000Z
# data_updated_at                                                2024-11-15T21:55:17.000Z
# columns_name                          [Market Location, County, FCC Accepted, FMNP, ...
# columns_field_name                    [market_location, county, fca, fmnp, georefere...
# columns_datatype                      [Text, Text, Text, Text, Point, Text, Number, ...
# columns_description                   [General place where the market is set up., Co...
# columns_format                        [{'align': 'left'}, {'align': 'left'}, {'align...
# download_count                                                                    29865
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2022-07-12T21:04:31.000Z
# page_views.page_views_last_week                                                     165
# page_views.page_views_last_month                                                    689
# page_views.page_views_total                                                      118360
# page_views.page_views_last_week_log                                            7.375039
# page_views.page_views_last_month_log                                           9.430453
# page_views.page_views_total_log                                               16.852834
#
#                                                                                      91  \
# name                                      Spring Farmers' Markets in New York State Map
# id                                                                            ezkt-j7iy
# resource_name                                                                      None
# parent_fxf                                                       [qq4h-8p86, wseq-ucz9]
# description                           In the past decade the number of farmers' mark...
# attribution                           New York State Department of Agriculture and M...
# attribution_link                      http://www.agriculture.ny.gov/AP/CommunityFarm...
# contact_email                                                       opendata@its.ny.gov
# type                                                                                map
# updatedAt                                                      2024-11-15T21:55:17.000Z
# createdAt                                                      2022-06-30T17:52:15.000Z
# metadata_updated_at                                            2022-07-06T00:10:30.000Z
# data_updated_at                                                2024-11-15T21:55:17.000Z
# columns_name                                                                         []
# columns_field_name                                                                   []
# columns_datatype                                                                     []
# columns_description                                                                  []
# columns_format                                                                       []
# download_count                                                                     6039
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                              visualization_canvas_map
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2022-06-30T17:53:27.000Z
# page_views.page_views_last_week                                                    1302
# page_views.page_views_last_month                                                   4480
# page_views.page_views_total                                                      118209
# page_views.page_views_last_week_log                                           10.347621
# page_views.page_views_last_month_log                                          12.129605
# page_views.page_views_total_log                                               16.850993
#
#                                                                                      92  \
# name                                  COVID-19 Daily Counts of Cases, Hospitalizatio...
# id                                                                            rc75-m7u3
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           Daily count of NYC residents who tested positi...
# attribution                             Department of Health and Mental Hygiene (DOHMH)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T20:32:00.000Z
# createdAt                                                      2020-04-30T17:15:03.000Z
# metadata_updated_at                                            2024-11-30T20:31:56.000Z
# data_updated_at                                                2024-11-30T20:32:00.000Z
# columns_name                          [SI_CASE_COUNT_7DAY_AVG, BK_DEATH_COUNT_7DAY_A...
# columns_field_name                    [si_case_count_7day_avg, bk_death_count_7day_a...
# columns_datatype                      [Number, Number, Number, Number, Number, Numbe...
# columns_description                   [, , , , , , , , , , , , , , , , , , , , , , ,...
# columns_format                        [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2023-12-11T18:42:39.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      93  \
# name                                  Hospital Inpatient Cost Transparency: Beginnin...
# id                                                                            7dtz-qxmr
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           This dataset contains information submitted by...
# attribution                                         New York State Department of Health
# attribution_link                            http://www.health.ny.gov/statistics/sparcs/
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-09-12T12:34:14.000Z
# createdAt                                                      2013-11-20T21:05:35.000Z
# metadata_updated_at                                            2024-09-12T12:34:14.000Z
# data_updated_at                                                2024-09-10T16:43:14.000Z
# columns_name                          [Median Cost, APR Severity of Illness Code, Me...
# columns_field_name                    [median_cost, apr_severity_of_illness_code, me...
# columns_datatype                      [Number, Number, Number, Text, Text, Number, N...
# columns_description                   [The median cost for services. \n, The APR-DRG...
# columns_format                        [{'precision': '2', 'align': 'right', 'currenc...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2018-01-18T19:46:00.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      94  \
# name                                                                  Jobs NYC Postings
# id                                                                            kpav-sd4t
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           This dataset contains current job postings ava...
# attribution                           Department of Citywide Administrative Services...
# attribution_link                                              https://cityjobs.nyc.gov/
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-26T20:04:31.000Z
# createdAt                                                      2013-04-18T17:40:16.000Z
# metadata_updated_at                                            2024-05-14T14:41:29.000Z
# data_updated_at                                                2024-11-26T20:04:31.000Z
# columns_name                          [Process Date, Additional Information, To Appl...
# columns_field_name                    [process_date, additional_information, to_appl...
# columns_datatype                      [Calendar date, Text, Text, Text, Text, Text, ...
# columns_description                   [Dataset created date., Additional information...
# columns_format                        [{'view': 'date'}, {}, {}, {}, {}, {}, {}, {'v...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2020-01-08T15:02:18.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      95  \
# name                                    Lottery Pick 10 Winning Numbers: Beginning 1987
# id                                                                            bycu-cw7c
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           Go to http://on.ny.gov/1Cx6Zls on the New York...
# attribution                                            New York State Gaming Commission
# attribution_link                      http://nylottery.ny.gov/wps/portal/Home/Lotter...
# contact_email                                                       opendata@its.ny.gov
# type                                                                            dataset
# updatedAt                                                      2024-11-30T11:03:47.000Z
# createdAt                                                      2013-02-26T19:37:05.000Z
# metadata_updated_at                                            2024-11-30T11:03:46.000Z
# data_updated_at                                                2024-11-30T11:03:47.000Z
# columns_name                                               [Draw Date, Winning Numbers]
# columns_field_name                                         [draw_date, winning_numbers]
# columns_datatype                                                  [Calendar date, Text]
# columns_description                                        [Draw date, Winning Numbers]
# columns_format                                [{'view': 'date', 'align': 'center'}, {}]
# download_count                                                                    21547
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-04-27T15:33:34.000Z
# page_views.page_views_last_week                                                     146
# page_views.page_views_last_month                                                    522
# page_views.page_views_total                                                      116120
# page_views.page_views_last_week_log                                            7.199672
# page_views.page_views_last_month_log                                           9.030667
# page_views.page_views_total_log                                               16.825269
#
#                                                                                      96  \
# name                                                   Street Hail Livery (SHL) Permits
# id                                                                            yhuu-4pt3
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>Please Note:</b> This dataset, which includ...
# attribution                                         Taxi and Limousine Commission (TLC)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T20:07:39.000Z
# createdAt                                                      2014-10-29T17:42:50.000Z
# metadata_updated_at                                            2024-01-17T20:04:38.000Z
# data_updated_at                                                2024-11-30T20:07:39.000Z
# columns_name                          [DMV License Plate Number, Last Time Updated, ...
# columns_field_name                    [dmv_license_plate_number, time_updated, suspe...
# columns_datatype                      [Text, Text, Calendar date, Text, Text, Text, ...
# columns_description                   [DMV License Plate Number\n, Last Time Updated...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2024-01-17T20:04:38.000Z
# page_views.page_views_last_week                                                       1
# page_views.page_views_last_month                                                     10
# page_views.page_views_total                                                          58
# page_views.page_views_last_week_log                                                 1.0
# page_views.page_views_last_month_log                                           3.459432
# page_views.page_views_total_log                                                5.882643
#
#                                                                                      97  \
# name                                         NYPD Complaint Data Current (Year To Date)
# id                                                                            5uac-w243
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           This dataset includes all valid felony, misdem...
# attribution                                                    Police Department (NYPD)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-10-21T19:45:45.000Z
# createdAt                                                      2016-10-28T22:37:30.000Z
# metadata_updated_at                                            2024-10-21T19:42:20.000Z
# data_updated_at                                                2024-10-21T19:45:45.000Z
# columns_name                          [CMPLNT_FR_DT, LAW_CAT_CD, BORO_NM, CRM_ATPT_C...
# columns_field_name                    [cmplnt_fr_dt, law_cat_cd, boro_nm, crm_atpt_c...
# columns_datatype                      [Calendar date, Text, Text, Text, Calendar dat...
# columns_description                   [Exact date of occurrence for the reported eve...
# columns_format                        [{'view': 'date', 'align': 'left'}, {}, {}, {}...
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2022-06-09T15:48:40.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
#                                                                                      98  \
# name                                  Index Crimes by County and Agency: Beginning 1990
# id                                                                            ca8h-8gjq
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           The Division of Criminal Justice Services (DCJ...
# attribution                           New York State Division of Criminal Justice Se...
# attribution_link                      http://www.criminaljustice.ny.gov/crimnet/ojsa...
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-13T20:05:21.000Z
# createdAt                                                      2013-02-15T20:06:23.000Z
# metadata_updated_at                                            2024-11-13T20:05:16.000Z
# data_updated_at                                                2024-11-13T20:05:21.000Z
# columns_name                          [Agency, County, Year, Months Reported, Index ...
# columns_field_name                    [agency, county, year, months_reported, total_...
# columns_datatype                      [Text, Text, Number, Number, Number, Number, N...
# columns_description                   [Police Department that reported the crime., L...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                    11107
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2021-06-29T18:05:50.000Z
# page_views.page_views_last_week                                                     141
# page_views.page_views_last_month                                                    877
# page_views.page_views_total                                                      113776
# page_views.page_views_last_week_log                                            7.149747
# page_views.page_views_last_month_log                                           9.778077
# page_views.page_views_total_log                                               16.795849
#
#                                                                                      99
# name                                  TLC Approved LabCorp Patient Services Drug Tes...
# id                                                                            xzxm-9msq
# resource_name                                                                      None
# parent_fxf                                                                  [pe54-wf39]
# description                           List of TLC approved LabCorp Drug Test Locatio...
# attribution                                         Taxi and Limousine Commission (TLC)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                                map
# updatedAt                                                      2024-03-08T23:29:06.000Z
# createdAt                                                      2023-03-02T14:59:11.000Z
# metadata_updated_at                                            2023-12-28T21:55:14.000Z
# data_updated_at                                                2024-03-08T23:29:06.000Z
# columns_name                                                                         []
# columns_field_name                                                                   []
# columns_datatype                                                                     []
# columns_description                                                                  []
# columns_format                                                                       []
# download_count                                                                        0
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                              visualization_canvas_map
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2023-12-28T21:55:14.000Z
# page_views.page_views_last_week                                                       0
# page_views.page_views_last_month                                                      0
# page_views.page_views_total                                                           0
# page_views.page_views_last_week_log                                                 NaN
# page_views.page_views_last_month_log                                                NaN
# page_views.page_views_total_log                                                     NaN
#
# [32 rows x 100 columns]

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

datasets = client.datasets()

print(f'object type: {type(datasets)}')
print(f'Number of datasets on NYC Open Data: {len(datasets):,}.')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# object type: <class 'list'>
# Number of datasets on NYC Open Data: 3,235.

# %%
# review type about first dataset
print(type(datasets[0]))
# Out:
# <class 'dict'>

# %%
# review information about keys first dataset
datasets[0].keys()
# Out:
# dict_keys(['resource', 'classification', 'metadata', 'permalink', 'link', 'owner', 'creator'])

# %%
# review information about resource key
resources = datasets[0]['resource'].items()

for key, value in resources:
    print(f'{key}: {value}\n')
# Out:
# name: For Hire Vehicles (FHV) - Active
#
# id: 8wbx-tsch
#
# resource_name: None
#
# parent_fxf: []
#
# description: <b>PLEASE NOTE:</b> This dataset, which includes all TLC licensed for-hire vehicles which are in good standing and able to drive, is updated every day in the evening between 4-7pm. Please check the 'Last Update Date' field to make sure the list has updated successfully. 'Last Update Date'  should show either today or yesterday's date, depending on the time of day. If the list is outdated, please download the most recent list from the link below.
# http://www1.nyc.gov/assets/tlc/downloads/datasets/tlc_for_hire_vehicle_active_and_inactive.csv
#
# TLC authorized For-Hire vehicles that are active. This list is accurate to the date and time represented in the Last Date Updated and Last Time Updated fields. For inquiries about the contents of this dataset, please email licensinginquiries@tlc.nyc.gov.
#
# attribution: Taxi and Limousine Commission (TLC)
#
# attribution_link: None
#
# contact_email: None
#
# type: dataset
#
# updatedAt: 2024-11-30T20:05:48.000Z
#
# createdAt: 2015-07-16T17:33:32.000Z
#
# metadata_updated_at: 2022-09-06T21:05:32.000Z
#
# data_updated_at: 2024-11-30T20:05:48.000Z
#
# page_views: {'page_views_last_week': 6207, 'page_views_last_month': 31173, 'page_views_total': 2918394, 'page_views_last_week_log': 12.599912842187129, 'page_views_last_month_log': 14.928055661555316, 'page_views_total_log': 21.47674373221476}
#
# columns_name: ['Hack Up Date', 'Base Address', 'Order Date', 'Vehicle Year', 'Base Type', 'Base Name', 'Name', 'DMV License Plate Number', 'Last Date Updated', 'Base Telephone Number', 'Permit License Number', 'Active', 'Website', 'Vehicle VIN Number', 'VEH', 'Wheelchair Accessible', 'Reason', 'Last Time Updated', 'License Type', 'Expiration Date', 'Certification Date', 'Base Number', 'Vehicle License Number']
#
# columns_field_name: ['hack_up_date', 'base_address', 'order_date', 'vehicle_year', 'base_type', 'base_name', 'name', 'dmv_license_plate_number', 'last_date_updated', 'base_telephone_number', 'permit_license_number', 'active', 'website', 'vehicle_vin_number', 'veh', 'wheelchair_accessible', 'reason', 'last_time_updated', 'license_type', 'expiration_date', 'certification_date', 'base_number', 'vehicle_license_number']
#
# columns_datatype: ['Calendar date', 'Text', 'Calendar date', 'Number', 'Text', 'Text', 'Text', 'Text', 'Calendar date', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Calendar date', 'Calendar date', 'Text', 'Text']
#
# columns_description: ['Hack Up Date', 'Base Address', 'Date Suspension ordered\n', 'Vehicle Year', 'Base Type', 'Base Name', 'Owner Name\n', 'DMV License Plate Number', 'Last Date Updated', 'Base Telephone NumberBase Telephone Number', 'Permit License Number', 'Permit active or not\n', 'Base Website', 'Vehicle VIN Number', 'Hybrid vehicle indicator\n', 'Wheelchair Accessible Indicator\n', 'Reason Code A,B,C or G\n', 'Last Time Updated', 'TLC License Type\n', 'Expiration Date', 'Certification Date', 'Base Number', 'FHV Vehicle License Number']
#
# columns_format: [{'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date_time', 'align': 'left'}, {'precisionStyle': 'standard', 'noCommas': 'true', 'align': 'right'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}]
#
# download_count: 531300
#
# provenance: official
#
# lens_view_type: tabular
#
# lens_display_type: table
#
# locked: False
#
# blob_mime_type: None
#
# hide_from_data_json: False
#
# publication_date: 2021-04-05T13:20:47.000Z

# %% [markdown]
# Retrieve information about 311 dataset.

# %%
## Retrieve information about 311 dataset
# NYC 311 dataset identifier
socrata_dataset_identifier = 'erm2-nwe9'

# get the list of datasets once
datasets = client.datasets()

# loop through the datasets to find the one with the matching identifier
for idx, dataset in enumerate(datasets):
    if dataset['resource']['id'] == socrata_dataset_identifier:
        print('We found the NYC 311 dataset!')
        print(f'Index is: {idx}')
        
        dataset_index = idx
        break
# Out:
# We found the NYC 311 dataset!
# Index is: 5

# %%
# normalize JSON
df = pd.json_normalize(datasets[dataset_index]['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (1, 32)
#                                         name         id resource_name  \
# 0  311 Service Requests from 2010 to Present  erm2-nwe9          None
#
#   parent_fxf                                        description attribution  \
# 0         []  <b>NOTE:</b> The 311 dataset is currently show...         311
#
#   attribution_link contact_email     type                 updatedAt  ...  \
# 0             None          None  dataset  2024-11-30T02:32:46.000Z  ...
#
#   locked blob_mime_type hide_from_data_json          publication_date  \
# 0  False           None               False  2023-12-01T06:51:46.000Z
#
#   page_views.page_views_last_week page_views.page_views_last_month  \
# 0                            2548                            12514
#
#   page_views.page_views_total page_views.page_views_last_week_log  \
# 0                      907673                           11.315716
#
#    page_views.page_views_last_month_log page_views.page_views_total_log
# 0                             13.611371                       19.791815
#
# [1 rows x 32 columns]

# %%
# preview available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   name                                  1 non-null      object
#  1   id                                    1 non-null      object
#  2   resource_name                         0 non-null      object
#  3   parent_fxf                            1 non-null      object
#  4   description                           1 non-null      object
#  5   attribution                           1 non-null      object
#  6   attribution_link                      0 non-null      object
#  7   contact_email                         0 non-null      object
#  8   type                                  1 non-null      object
#  9   updatedAt                             1 non-null      object
#  10  createdAt                             1 non-null      object
#  11  metadata_updated_at                   1 non-null      object
#  12  data_updated_at                       1 non-null      object
#  13  columns_name                          1 non-null      object
#  14  columns_field_name                    1 non-null      object
#  15  columns_datatype                      1 non-null      object
#  16  columns_description                   1 non-null      object
#  17  columns_format                        1 non-null      object
#  18  download_count                        1 non-null      int64
#  19  provenance                            1 non-null      object
#  20  lens_view_type                        1 non-null      object
#  21  lens_display_type                     1 non-null      object
#  22  locked                                1 non-null      bool
#  23  blob_mime_type                        0 non-null      object
#  24  hide_from_data_json                   1 non-null      bool
#  25  publication_date                      1 non-null      object
#  26  page_views.page_views_last_week       1 non-null      int64
#  27  page_views.page_views_last_month      1 non-null      int64
#  28  page_views.page_views_total           1 non-null      int64
#  29  page_views.page_views_last_week_log   1 non-null      float64
#  30  page_views.page_views_last_month_log  1 non-null      float64
#  31  page_views.page_views_total_log       1 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(23)
# memory usage: 370.0+ bytes

# %%
# preview columns and values
df.T
# Out:
#                                                                                       0
# name                                          311 Service Requests from 2010 to Present
# id                                                                            erm2-nwe9
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           <b>NOTE:</b> The 311 dataset is currently show...
# attribution                                                                         311
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                            dataset
# updatedAt                                                      2024-11-30T02:32:46.000Z
# createdAt                                                      2011-10-10T05:52:17.000Z
# metadata_updated_at                                            2024-05-28T20:32:16.000Z
# data_updated_at                                                2024-11-30T02:32:46.000Z
# columns_name                          [Bridge Highway Name, Borough, Bridge Highway ...
# columns_field_name                    [bridge_highway_name, borough, bridge_highway_...
# columns_datatype                      [Text, Text, Text, Text, Text, Number, Text, C...
# columns_description                   [If the incident is identified as a Bridge/Hig...
# columns_format                        [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                                   444219
# provenance                                                                     official
# lens_view_type                                                                  tabular
# lens_display_type                                                                 table
# locked                                                                            False
# blob_mime_type                                                                     None
# hide_from_data_json                                                               False
# publication_date                                               2023-12-01T06:51:46.000Z
# page_views.page_views_last_week                                                    2548
# page_views.page_views_last_month                                                  12514
# page_views.page_views_total                                                      907673
# page_views.page_views_last_week_log                                           11.315716
# page_views.page_views_last_month_log                                          13.611371
# page_views.page_views_total_log                                               19.791815

# %% [markdown]
# ## 5.3  Metadata API
# Socrata's [Metadata API](https://dev.socrata.com/docs/other/metadata#?route=overview).

# %% [markdown]
# Sodapy `.get_metadata()` method: Retrieve the metadata for a particular dataset.

# %% [markdown]
# ### Using Socrata API URL

# %%
# example of the Metadata API with 311 dataset
# https://dev.socrata.com/docs/other/metadata#?route=overview

# all datasets on NYC Open Data, and expand nested columns
url = 'https://data.cityofnewyork.us/api/views/'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#           id                                              name assetType  \
# 0  6xyb-j5pk                          NYC Address Points (Map)       map
# 1  uf93-f8nk                                NYC Address Points   dataset
# 2  b7aj-ck5a  NYC Greenhouse Gas Emissions Municipal Inventory   dataset
# 3  3g6p-4u5s                         Building Footprints (Map)       map
# 4  u9wf-3gbt                     Building Footprints (P Layer)   dataset
#
#    averageRating         category   createdAt  \
# 0              0  City Government  1732652029
# 1              0  City Government  1732641922
# 2              0      Environment  1732116009
# 3              0  City Government  1731516162
# 4              0  City Government  1731513726
#
#                                          description  \
# 0  Address points were developed to supplement th...
# 1  Address points were developed to supplement th...
# 2  The Inventory of New York City Greenhouse Gas ...
# 3  Shapefile of footprint outlines of buildings i...
# 4  Shapefile of footprint outlines of buildings i...
#
#                 displayType  downloadCount  hideFromCatalog  ...  blobId  \
# 0  visualization_canvas_map              0            False  ...     NaN
# 1                     table             13            False  ...     NaN
# 2                     table             37            False  ...     NaN
# 3  visualization_canvas_map              1            False  ...     NaN
# 4                     table             20            False  ...     NaN
#
#    blobMimeType rowIdentifierColumnId  queryString  ratings  indexUpdatedAt  \
# 0           NaN                   NaN          NaN      NaN             NaN
# 1           NaN                   NaN          NaN      NaN             NaN
# 2           NaN                   NaN          NaN      NaN             NaN
# 3           NaN                   NaN          NaN      NaN             NaN
# 4           NaN                   NaN          NaN      NaN             NaN
#
#   childViews  iconUrl  previewImageId  disabledFeatureFlags
# 0        NaN      NaN             NaN                   NaN
# 1        NaN      NaN             NaN                   NaN
# 2        NaN      NaN             NaN                   NaN
# 3        NaN      NaN             NaN                   NaN
# 4        NaN      NaN             NaN                   NaN
#
# [5 rows x 51 columns]

# %%
# preview available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3235 entries, 0 to 3234
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3235 non-null   object
#  1   name                      3235 non-null   object
#  2   assetType                 3235 non-null   object
#  3   averageRating             3235 non-null   int64
#  4   category                  3135 non-null   object
#  5   createdAt                 3235 non-null   int64
#  6   description               3170 non-null   object
#  7   displayType               3235 non-null   object
#  8   downloadCount             3235 non-null   int64
#  9   hideFromCatalog           3235 non-null   bool
#  10  hideFromDataJson          3235 non-null   bool
#  11  locked                    3235 non-null   bool
#  12  modifyingViewUid          271 non-null    object
#  13  newBackend                3235 non-null   bool
#  14  numberOfComments          3235 non-null   int64
#  15  oid                       3235 non-null   int64
#  16  provenance                3235 non-null   object
#  17  publicationAppendEnabled  3235 non-null   bool
#  18  publicationDate           3210 non-null   float64
#  19  publicationGroup          3235 non-null   int64
#  20  publicationStage          3235 non-null   object
#  21  rowsUpdatedAt             3058 non-null   float64
#  22  rowsUpdatedBy             2796 non-null   object
#  23  tableId                   3235 non-null   int64
#  24  totalTimesRated           3235 non-null   int64
#  25  viewCount                 3235 non-null   int64
#  26  viewLastModified          3235 non-null   int64
#  27  viewType                  3235 non-null   object
#  28  approvals                 3235 non-null   object
#  29  clientContext             3235 non-null   object
#  30  grants                    3235 non-null   object
#  31  metadata                  3235 non-null   object
#  32  owner                     3235 non-null   object
#  33  rights                    3235 non-null   object
#  34  tableAuthor               3235 non-null   object
#  35  flags                     3235 non-null   object
#  36  tags                      2451 non-null   object
#  37  locale                    383 non-null    object
#  38  rowClass                  1661 non-null   object
#  39  blobFilename              204 non-null    object
#  40  blobFileSize              204 non-null    float64
#  41  blobId                    204 non-null    object
#  42  blobMimeType              204 non-null    object
#  43  rowIdentifierColumnId     57 non-null     float64
#  44  queryString               1 non-null      object
#  45  ratings                   24 non-null     object
#  46  indexUpdatedAt            1785 non-null   float64
#  47  childViews                37 non-null     object
#  48  iconUrl                   41 non-null     object
#  49  previewImageId            110 non-null    object
#  50  disabledFeatureFlags      16 non-null     object
# dtypes: bool(5), float64(5), int64(10), object(31)
# memory usage: 1.2+ MB

# %%
# Discovery API, 311 dataset
# instead of expanding nested columns, let's keep only top-level columns
url = 'https://data.cityofnewyork.us/api/views/erm2-nwe9'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json()  

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'locked', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowIdentifierColumnId', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'clientContext', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
# convert to df
df = pd.DataFrame([data_dict])

df.head()
# Out:
#           id                                       name assetType attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present   dataset         311
#
#    averageRating         category   createdAt  \
# 0              0  Social Services  1318225937
#
#                                          description displayType  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...       table
#
#    downloadCount  ...                                      clientContext  \
# 0         444226  ...  {'clientContextVariables': [], 'inheritedVaria...
#
#                                              columns  \
# 0  [{'id': 585605889, 'name': 'Unique Key', 'data...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                                             metadata  \
# 0  {'rdfSubject': '0', 'rdfClass': '', 'jsonQuery...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                query  rights  \
# 0  {'orderBys': [{'ascending': False, 'expression...  [read]
#
#                                          tableAuthor  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                 tags  \
# 0  [311, 311 service requests, city government, s...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...
#
# [1 rows x 41 columns]

# %%
# view columns
# notice the decrease in number of columns compared to the previous example
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1 non-null      object
#  1   name                      1 non-null      object
#  2   assetType                 1 non-null      object
#  3   attribution               1 non-null      object
#  4   averageRating             1 non-null      int64
#  5   category                  1 non-null      object
#  6   createdAt                 1 non-null      int64
#  7   description               1 non-null      object
#  8   displayType               1 non-null      object
#  9   downloadCount             1 non-null      int64
#  10  hideFromCatalog           1 non-null      bool
#  11  hideFromDataJson          1 non-null      bool
#  12  locked                    1 non-null      bool
#  13  newBackend                1 non-null      bool
#  14  numberOfComments          1 non-null      int64
#  15  oid                       1 non-null      int64
#  16  provenance                1 non-null      object
#  17  publicationAppendEnabled  1 non-null      bool
#  18  publicationDate           1 non-null      int64
#  19  publicationGroup          1 non-null      int64
#  20  publicationStage          1 non-null      object
#  21  rowClass                  1 non-null      object
#  22  rowIdentifierColumnId     1 non-null      int64
#  23  rowsUpdatedAt             1 non-null      int64
#  24  rowsUpdatedBy             1 non-null      object
#  25  tableId                   1 non-null      int64
#  26  totalTimesRated           1 non-null      int64
#  27  viewCount                 1 non-null      int64
#  28  viewLastModified          1 non-null      int64
#  29  viewType                  1 non-null      object
#  30  approvals                 1 non-null      object
#  31  clientContext             1 non-null      object
#  32  columns                   1 non-null      object
#  33  grants                    1 non-null      object
#  34  metadata                  1 non-null      object
#  35  owner                     1 non-null      object
#  36  query                     1 non-null      object
#  37  rights                    1 non-null      object
#  38  tableAuthor               1 non-null      object
#  39  tags                      1 non-null      object
#  40  flags                     1 non-null      object
# dtypes: bool(5), int64(13), object(23)
# memory usage: 421.0+ bytes

# %%
# example of the Metadata API with 311 dataset
# https://dev.socrata.com/docs/other/metadata#?route=overview

# all datasets on NYC Open Data, notice the metadata in the URL
url = 'https://data.cityofnewyork.us/api/views/metadata/v1/'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#           id                                              name  \
# 0  6xyb-j5pk                          NYC Address Points (Map)
# 1  uf93-f8nk                                NYC Address Points
# 2  b7aj-ck5a  NYC Greenhouse Gas Emissions Municipal Inventory
# 3  3g6p-4u5s                         Building Footprints (Map)
# 4  u9wf-3gbt                     Building Footprints (P Layer)
#
#                                          attribution  \
# 0          Office of Technology and Innovation (OTI)
# 1          Office of Technology and Innovation (OTI)
# 2  Mayor's Office of Climate and Environmental Ju...
# 3          Office of Technology and Innovation (OTI)
# 4          Office of Technology and Innovation (OTI)
#
#                                      attributionLink         category  \
# 0                                               None  City Government
# 1                                               None  City Government
# 2  https://climate.cityofnewyork.us/initiatives/n...      Environment
# 3                                               None  City Government
# 4                                               None  City Government
#
#                   createdAt             dataUpdatedAt  \
# 0  2024-11-26T20:13:49+0000  2024-11-26T18:02:43+0000
# 1  2024-11-26T17:25:22+0000  2024-11-26T18:02:43+0000
# 2  2024-11-20T15:20:09+0000  2024-11-20T15:48:44+0000
# 3  2024-11-13T16:42:42+0000  2024-11-26T17:51:19+0000
# 4  2024-11-13T16:02:06+0000  2024-11-26T17:33:50+0000
#
#                                             dataUri  \
# 0  https://data.cityofnewyork.us/resource/6xyb-j5pk
# 1  https://data.cityofnewyork.us/resource/uf93-f8nk
# 2  https://data.cityofnewyork.us/resource/b7aj-ck5a
# 3  https://data.cityofnewyork.us/resource/3g6p-4u5s
# 4  https://data.cityofnewyork.us/resource/u9wf-3gbt
#
#                                          description                 domain  \
# 0  Address points were developed to supplement th...  data.cityofnewyork.us
# 1  Address points were developed to supplement th...  data.cityofnewyork.us
# 2  The Inventory of New York City Greenhouse Gas ...  data.cityofnewyork.us
# 3  Shapefile of footprint outlines of buildings i...  data.cityofnewyork.us
# 4  Shapefile of footprint outlines of buildings i...  data.cityofnewyork.us
#
#    ...  hideFromCatalog  hideFromDataJson  license         metadataUpdatedAt  \
# 0  ...            False             False     None  2024-11-26T20:14:56+0000
# 1  ...            False             False     None  2024-11-26T20:13:07+0000
# 2  ...            False             False     None  2024-11-20T15:49:27+0000
# 3  ...            False             False     None  2024-11-13T16:47:48+0000
# 4  ...            False             False     None  2024-11-26T17:32:07+0000
#
#   provenance                 updatedAt  \
# 0   OFFICIAL  2024-11-26T20:14:56+0000
# 1   OFFICIAL  2024-11-26T20:13:07+0000
# 2   OFFICIAL  2024-11-20T15:49:49+0000
# 3   OFFICIAL  2024-11-13T16:47:48+0000
# 4   OFFICIAL  2024-11-26T17:32:07+0000
#
#                                       webUri  \
# 0  https://data.cityofnewyork.us/d/6xyb-j5pk
# 1  https://data.cityofnewyork.us/d/uf93-f8nk
# 2  https://data.cityofnewyork.us/d/b7aj-ck5a
# 3  https://data.cityofnewyork.us/d/3g6p-4u5s
# 4  https://data.cityofnewyork.us/d/u9wf-3gbt
#
#                                            approvals  \
# 0  [{'reviewedAt': 1732652072, 'reviewedAutomatic...
# 1  [{'reviewedAt': 1732651869, 'reviewedAutomatic...
# 2  [{'reviewedAt': 1732117789, 'reviewedAutomatic...
# 3  [{'reviewedAt': 1731516188, 'reviewedAutomatic...
# 4  [{'reviewedAt': 1731516092, 'reviewedAutomatic...
#
#                                         customFields  \
# 0  {'Update': {'Automation': 'No', 'Date Made Pub...
# 1  {'Update': {'Automation': 'No', 'Date Made Pub...
# 2  {'Update': {'Automation': 'No', 'Date Made Pub...
# 3  {'Update': {'Automation': 'No', 'Date Made Pub...
# 4  {'Update': {'Automation': 'No', 'Date Made Pub...
#
#                                                 tags
# 0                                               None
# 1                                    [address point]
# 2  [greenhouse gas emissions, greenhouse, fuel, e...
# 3                            [footprints, buildings]
# 4                  [building, footprint, footprints]
#
# [5 rows x 21 columns]

# %%
# preview available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3235 entries, 0 to 3234
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3235 non-null   object
#  1   name               3235 non-null   object
#  2   attribution        3168 non-null   object
#  3   attributionLink    449 non-null    object
#  4   category           3135 non-null   object
#  5   createdAt          3235 non-null   object
#  6   dataUpdatedAt      3058 non-null   object
#  7   dataUri            3235 non-null   object
#  8   description        3170 non-null   object
#  9   domain             3235 non-null   object
#  10  externalId         0 non-null      float64
#  11  hideFromCatalog    3235 non-null   bool
#  12  hideFromDataJson   3235 non-null   bool
#  13  license            79 non-null     object
#  14  metadataUpdatedAt  3235 non-null   object
#  15  provenance         3235 non-null   object
#  16  updatedAt          3235 non-null   object
#  17  webUri             3235 non-null   object
#  18  approvals          3235 non-null   object
#  19  customFields       3233 non-null   object
#  20  tags               2451 non-null   object
# dtypes: bool(2), float64(1), object(18)
# memory usage: 486.6+ KB

# %%
# Metadata API for 311 dataset
url = 'https://data.cityofnewyork.us/api/views/metadata/v1/erm2-nwe9/'

# Fetch the JSON data from the web
response = requests.get(url)

# Parse the JSON response
data_dict = response.json()

# convert to a df
df = pd.DataFrame([data_dict])

# preview data
df.head()
# Out:
#           id                                       name attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present         311
#
#   attributionLink         category                 createdAt  \
# 0            None  Social Services  2011-10-10T05:52:17+0000
#
#               dataUpdatedAt                                           dataUri  \
# 0  2024-11-30T02:32:46+0000  https://data.cityofnewyork.us/resource/erm2-nwe9
#
#                                          description                 domain  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...  data.cityofnewyork.us
#
#    ... hideFromCatalog  hideFromDataJson  license         metadataUpdatedAt  \
# 0  ...           False             False     None  2024-05-28T20:32:16+0000
#
#   provenance                 updatedAt  \
# 0   OFFICIAL  2024-05-28T20:32:16+0000
#
#                                       webUri  \
# 0  https://data.cityofnewyork.us/d/erm2-nwe9
#
#                                            approvals  \
# 0  [{'reviewedAt': 1524193398, 'reviewedAutomatic...
#
#                                         customFields  \
# 0  {'Update': {'Automation': 'Yes', 'Date Made Pu...
#
#                                                 tags
# 0  [311, 311 service requests, city government, s...
#
# [1 rows x 21 columns]

# %%
# preview available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1 non-null      object
#  1   name               1 non-null      object
#  2   attribution        1 non-null      object
#  3   attributionLink    0 non-null      object
#  4   category           1 non-null      object
#  5   createdAt          1 non-null      object
#  6   dataUpdatedAt      1 non-null      object
#  7   dataUri            1 non-null      object
#  8   description        1 non-null      object
#  9   domain             1 non-null      object
#  10  externalId         0 non-null      object
#  11  hideFromCatalog    1 non-null      bool
#  12  hideFromDataJson   1 non-null      bool
#  13  license            0 non-null      object
#  14  metadataUpdatedAt  1 non-null      object
#  15  provenance         1 non-null      object
#  16  updatedAt          1 non-null      object
#  17  webUri             1 non-null      object
#  18  approvals          1 non-null      object
#  19  customFields       1 non-null      object
#  20  tags               1 non-null      object
# dtypes: bool(2), object(19)
# memory usage: 282.0+ bytes

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# dataset id for NYC 311 on NYC Open Data on Socrata
socrata_dataset_identifier = 'erm2-nwe9'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

# similar to: 'https://data.cityofnewyork.us/api/views/metadata/v1/'
metadata = client.get_metadata(socrata_dataset_identifier)

metadata.keys()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'locked', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowIdentifierColumnId', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'clientContext', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
# convert to df
df = pd.DataFrame([metadata])

# preview data
df.head()
# Out:
#           id                                       name assetType attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present   dataset         311
#
#    averageRating         category   createdAt  \
# 0              0  Social Services  1318225937
#
#                                          description displayType  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...       table
#
#    downloadCount  ...                                      clientContext  \
# 0         444226  ...  {'clientContextVariables': [], 'inheritedVaria...
#
#                                              columns  \
# 0  [{'id': 585605889, 'name': 'Unique Key', 'data...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                                             metadata  \
# 0  {'rdfSubject': '0', 'rdfClass': '', 'jsonQuery...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                query  rights  \
# 0  {'orderBys': [{'ascending': False, 'expression...  [read]
#
#                                          tableAuthor  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                 tags  \
# 0  [311, 311 service requests, city government, s...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...
#
# [1 rows x 41 columns]

# %%
# preview available columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1 non-null      object
#  1   name                      1 non-null      object
#  2   assetType                 1 non-null      object
#  3   attribution               1 non-null      object
#  4   averageRating             1 non-null      int64
#  5   category                  1 non-null      object
#  6   createdAt                 1 non-null      int64
#  7   description               1 non-null      object
#  8   displayType               1 non-null      object
#  9   downloadCount             1 non-null      int64
#  10  hideFromCatalog           1 non-null      bool
#  11  hideFromDataJson          1 non-null      bool
#  12  locked                    1 non-null      bool
#  13  newBackend                1 non-null      bool
#  14  numberOfComments          1 non-null      int64
#  15  oid                       1 non-null      int64
#  16  provenance                1 non-null      object
#  17  publicationAppendEnabled  1 non-null      bool
#  18  publicationDate           1 non-null      int64
#  19  publicationGroup          1 non-null      int64
#  20  publicationStage          1 non-null      object
#  21  rowClass                  1 non-null      object
#  22  rowIdentifierColumnId     1 non-null      int64
#  23  rowsUpdatedAt             1 non-null      int64
#  24  rowsUpdatedBy             1 non-null      object
#  25  tableId                   1 non-null      int64
#  26  totalTimesRated           1 non-null      int64
#  27  viewCount                 1 non-null      int64
#  28  viewLastModified          1 non-null      int64
#  29  viewType                  1 non-null      object
#  30  approvals                 1 non-null      object
#  31  clientContext             1 non-null      object
#  32  columns                   1 non-null      object
#  33  grants                    1 non-null      object
#  34  metadata                  1 non-null      object
#  35  owner                     1 non-null      object
#  36  query                     1 non-null      object
#  37  rights                    1 non-null      object
#  38  tableAuthor               1 non-null      object
#  39  tags                      1 non-null      object
#  40  flags                     1 non-null      object
# dtypes: bool(5), int64(13), object(23)
# memory usage: 421.0+ bytes

# %%
# close connection
client.close()
