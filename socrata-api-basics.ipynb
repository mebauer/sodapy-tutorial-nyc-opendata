# %% [markdown]
# # Socrata API Basics
# ## Socrata Open Data API (SODA) Tutorial with Python and NYC Open Data
# Author: Mark Bauer

# %% [markdown]
# Table of Contents
# =================
#
#    1. Introduction
#    2. Sodapy
#    3. Importing Libraries
#    4. Sodapy Socrata Class
#    5. Socrata APIs
#        - 5.1 Socrata API
#        - 5.2 Discovery API
#        - 5.3 Metadata API

# %% [markdown]
# # 1. Introduction
# This notebook demonstrates how to interact with the [Socrata Open Data API](https://dev.socrata.com/) in Python and explores different methods for retrieving data from Socrata-based open data portals. Additionally, we'll explore the library [sodapy](https://github.com/xmunoz/sodapy), a Python client for the Socrata Open Data API.
#
# Not only will we learn how to fetch data, but we'll also explore Socrata's available metadata using the [Discovery](https://dev.socrata.com/docs/other/discovery#?route=overview) and [Metadata](https://dev.socrata.com/docs/other/metadata#?route=overview) APIs. These endpoints are often underutilized, but they offer valuable insights, such as dataset download counts, page views, and more.
#
# While the main focus is on understanding how to interact with the Socrata API, we'll use the sodapy library throughout the examples, as it provides a straightforward interface for working with the Socrata API in Python. Both the Socrata API endpoint as well as sodapy code snippets will be provided to give you flexibility in how you approach your data retrieval. For this tutorial, the code is written in Python and will use data from NYC Open Data as an example.
#
# Finally, I encourage you to read the [Socrata Documentation](https://dev.socrata.com/), as well as the [API Docs](https://dev.socrata.com/docs/endpoints) for a comprehensive understanding. This project highlights some of the most popular methods for working with the API, but it is by no means exhaustive.

# %% [markdown]
# # 2. Sodapy
#
# [Sodapy](https://github.com/xmunoz/sodapy) is a python client for the Socrata Open Data API. In order use sodapy, a source domain (i.e. the Socrata Open Data source you are trying to connect to) needs to be passed to the Socrata class. Additionally, if a user wants to query a specific dataset on Socrata Open Data, then the dataset identifier (i.e. the dataset id on the given source domain) needs to be passed as well. Below, we identify NYC Open Data's source domain: `data.cityofnewyork.us` and the dataset identifier for the NYC 311 dataset: `erm2-nwe9`. The screenshot below displays where we retrieve this information.
#
# This is my preferred method for fetching data from NYC Open Data. However, please note that the Sodapy project is now archived on GitHub and is read-only.
#
# ![nyc-311-api-docs](images/nyc-311-api-docs.png)
#
# Source: https://dev.socrata.com/foundry/data.cityofnewyork.us/erm2-nwe9
#
# ![nyc-311-api-docs](images/nyc-311-api-docs.png)
#
# Screenshot: https://dev.socrata.com/foundry/data.cityofnewyork.us/erm2-nwe9

# %% [markdown]
# We will focus on three popular Sodapy methods:
# - `.get()`
# Read data from the requested resource (The Socrata API Endpoint)
#
# -  `.datasets()`
# Returns the list of datasets associated with a particular domain (Discovery API)
#
# - `.get_metadata()`
# Retrieve the metadata for a particular dataset (Metadata API)
#
# For a comprehensive list of other available APIs provided by Socrata, check out the [Other APIs](https://dev.socrata.com/docs/other/) page in the documentation.

# %% [markdown]
# ### Attention
# When querying all records, be sure to set the `limit` parameter to a value large enough to exceed the total number of records in your dataset. If the `limit` value is set to exactly the same number as the records returned, you likely haven’t retrieved all the data. To avoid this, choose a `limit` that is larger than the dataset’s total size.

# %% [markdown]
# # 3. Importing Libraries

# %%
# importing libraries
import pandas as pd
import requests
from sodapy import Socrata

# %%
# documention for installing watermark: https://github.com/rasbt/watermark, performed for reproducibility
# %reload_ext watermark
# %watermark -u -t -d -v -p pandas,sodapy
# Out:
# Last updated: 2024-12-02 21:35:35
#
# Python implementation: CPython
# Python version       : 3.11.0
# IPython version      : 8.6.0
#
# pandas: 1.5.1
# sodapy: 2.2.0

# %% [markdown]
# # 4. Sodapy Socrata Class

# %% [markdown]
# Note:
# `WARNING:root:Requests made without an app_token will be subject to strict throttling limits.`
#
# To avoid these limits, it's recommended to use an [app token](https://dev.socrata.com/docs/app-tokens.html) when making API requests.

# %%
# implementation in sodapy
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# Socrata(): The main class that interacts with the SODA API.

# the required arguments are:
#     domain: the domain you wish you to access
#     app_token: your Socrata application token
# simple requests are possible without an app_token, though these
# requests will be rate-limited.

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

# no app token is passed, and the timeout limit is 100 seconds

# examine object
print(client)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <sodapy.socrata.Socrata object at 0x15f16c490>

# %%
# print information about the Socrata object
print(f'type: {type(client)}')
# Out:
# type: <class 'sodapy.socrata.Socrata'>

# %%
# print attributes of object
for key, value in client.__dict__.items():
    print(f'{key}: {value}')
# Out:
# domain: data.cityofnewyork.us
# session: <requests.sessions.Session object at 0x15f16c510>
# uri_prefix: https://
# timeout: 100

# %% [markdown]
# # 5. Socrata APIs

# %% [markdown]
# ##  5.1 Socrata Open Data API
# [Socrata's Open Data API](https://dev.socrata.com/docs/endpoints).
#
# From [the docs](https://dev.socrata.com/docs/endpoints):
# >The “endpoint” of a SODA API is simply a unique URL that represents an object or collection of objects. Every Socrata dataset, and even every individual data record, has its own endpoint. The endpoint is what you’ll point your HTTP client at to interact with data resources.
# >
# >All resources are accessed through a common base path of /resource/ along with their dataset identifier.

# %% [markdown]
# In Sodapy, we use the `.get()` method: read data from the requested resource. Options for content_type are JSON, CSV, and XML. This method performs a get request on these type of URLs: https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=5.

# %% [markdown]
# ### Using Socrata API URL

# %%
# dataset: DEP Green Infrastructure https://data.cityofnewyork.us/Environment/DEP-Green-Infrastructure/spjh-pz7h
url = 'https://data.cityofnewyork.us/resource/bs59-f3nu.json'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#                                             the_geom  asset_id gi_id  \
# 0  {'type': 'Point', 'coordinates': [-73.81167623...     94002    1A
# 1  {'type': 'Point', 'coordinates': [-73.81228577...     94012  GS6A
# 2  {'type': 'Point', 'coordinates': [-73.81223444...     94017  GS8C
# 3  {'type': 'Point', 'coordinates': [-73.81205974...     94019  GS8E
# 4  {'type': 'Point', 'coordinates': [-73.81310191...     94021   10A
#
#   dep_contra  dep_cont_1 row_onsite           project_na asset_type  \
# 0  GQJA03-02           2        ROW  DDC JAM-003 Phase 2       ROWB
# 1  GQJA03-02           2        ROW  DDC JAM-003 Phase 2      ROWGS
# 2  GQJA03-02           2        ROW  DDC JAM-003 Phase 2      ROWGS
# 3  GQJA03-02           2        ROW  DDC JAM-003 Phase 2      ROWGS
# 4  GQJA03-02           2        ROW  DDC JAM-003 Phase 2       ROWB
#
#                            status    asset_x_co  ...  asset_leng asset_widt  \
# 0  Constructed (Full Maintenance)  1.036475e+06  ...        17.0        5.0
# 1  Constructed (Full Maintenance)  1.036305e+06  ...        13.0        3.5
# 2  Constructed (Full Maintenance)  1.036319e+06  ...        20.0        3.5
# 3  Constructed (Full Maintenance)  1.036368e+06  ...        20.0        3.5
# 4  Constructed (Full Maintenance)  1.036079e+06  ...        13.0        4.0
#
#   asset_area gi_feature           tree_latin          tree_commo  constructi  \
# 0       85.0   Standard  Chionanthus retusus  Chinese Fringetree   GCJA03-2A
# 1       45.5        NaN              No Tree                 N/A   GCJA03-2A
# 2       70.0        NaN              No Tree                 N/A   GCJA03-2A
# 3       70.0        NaN              No Tree                 N/A   GCJA03-2A
# 4       52.0   Standard    Quercus palustris             Pin Oak   GCJA03-2A
#
#    construc_1          program_ar   status_gro
# 0   Package-1  Right of Way (ROW)  Constructed
# 1   Package-1  Right of Way (ROW)  Constructed
# 2   Package-1  Right of Way (ROW)  Constructed
# 3   Package-1  Right of Way (ROW)  Constructed
# 4   Package-1  Right of Way (ROW)  Constructed
#
# [5 rows x 30 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   the_geom    1000 non-null   object
#  1   asset_id    1000 non-null   int64
#  2   gi_id       1000 non-null   object
#  3   dep_contra  1000 non-null   object
#  4   dep_cont_1  1000 non-null   int64
#  5   row_onsite  1000 non-null   object
#  6   project_na  1000 non-null   object
#  7   asset_type  1000 non-null   object
#  8   status      1000 non-null   object
#  9   asset_x_co  1000 non-null   float64
#  10  asset_y_co  1000 non-null   float64
#  11  borough     1000 non-null   object
#  12  sewer_type  1000 non-null   object
#  13  outfall     1000 non-null   object
#  14  nyc_waters  1000 non-null   object
#  15  bbl         1000 non-null   int64
#  16  secondary_  1000 non-null   int64
#  17  community_  1000 non-null   int64
#  18  city_counc  1000 non-null   int64
#  19  assembly_d  1000 non-null   int64
#  20  asset_leng  1000 non-null   float64
#  21  asset_widt  1000 non-null   float64
#  22  asset_area  1000 non-null   float64
#  23  gi_feature  900 non-null    object
#  24  tree_latin  994 non-null    object
#  25  tree_commo  994 non-null    object
#  26  constructi  994 non-null    object
#  27  construc_1  994 non-null    object
#  28  program_ar  1000 non-null   object
#  29  status_gro  1000 non-null   object
# dtypes: float64(5), int64(7), object(18)
# memory usage: 234.5+ KB

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# green infrastructure dataset identifier
socrata_dataset_identifier = 'bs59-f3nu'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=1000
)

# get data for the 311 dataset, limit to 5 rows
# notice the limit parameter
data = client.get(socrata_dataset_identifier)

# identify type of object returned
print(type(data))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# <class 'list'>

# %%
# preview first element in list, this is one record
data[0]
# Out:
# {'the_geom': {'type': 'Point',
#   'coordinates': [-73.81167623024226, 40.69138622900597]},
#  'asset_id': '94002.0',
#  'gi_id': '1A',
#  'dep_contra': 'GQJA03-02',
#  'dep_cont_1': '2',
#  'row_onsite': 'ROW',
#  'project_na': 'DDC JAM-003 Phase 2',
#  'asset_type': 'ROWB',
#  'status': 'Constructed (Full Maintenance)',
#  'asset_x_co': '1036475.27735',
#  'asset_y_co': '191223.227',
#  'borough': 'Queens',
#  'sewer_type': 'Combined',
#  'outfall': 'JAM-003',
#  'nyc_waters': 'Jamaica Bay and Tributaries',
#  'bbl': '4095890001.0',
#  'secondary_': '0.0',
#  'community_': '410.0',
#  'city_counc': '28.0',
#  'assembly_d': '32.0',
#  'asset_leng': '17.0',
#  'asset_widt': '5.0',
#  'asset_area': '85.0',
#  'gi_feature': 'Standard',
#  'tree_latin': 'Chionanthus retusus',
#  'tree_commo': 'Chinese Fringetree',
#  'constructi': 'GCJA03-2A',
#  'construc_1': 'Package-1',
#  'program_ar': 'Right of Way (ROW)',
#  'status_gro': 'Constructed'}

# %%
# convert list to a df
df = pd.DataFrame(data)

# sanity check
print(df.shape)
df.head()
# Out:
# (1000, 30)
#                                             the_geom asset_id gi_id  \
# 0  {'type': 'Point', 'coordinates': [-73.81167623...  94002.0    1A
# 1  {'type': 'Point', 'coordinates': [-73.81228577...  94012.0  GS6A
# 2  {'type': 'Point', 'coordinates': [-73.81223444...  94017.0  GS8C
# 3  {'type': 'Point', 'coordinates': [-73.81205974...  94019.0  GS8E
# 4  {'type': 'Point', 'coordinates': [-73.81310191...  94021.0   10A
#
#   dep_contra dep_cont_1 row_onsite           project_na asset_type  \
# 0  GQJA03-02          2        ROW  DDC JAM-003 Phase 2       ROWB
# 1  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 2  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 3  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 4  GQJA03-02          2        ROW  DDC JAM-003 Phase 2       ROWB
#
#                            status     asset_x_co  ... asset_leng asset_widt  \
# 0  Constructed (Full Maintenance)  1036475.27735  ...       17.0        5.0
# 1  Constructed (Full Maintenance)  1036305.46107  ...       13.0        3.5
# 2  Constructed (Full Maintenance)  1036319.11813  ...       20.0        3.5
# 3  Constructed (Full Maintenance)  1036367.52667  ...       20.0        3.5
# 4  Constructed (Full Maintenance)  1036078.81888  ...       13.0        4.0
#
#   asset_area gi_feature           tree_latin          tree_commo constructi  \
# 0       85.0   Standard  Chionanthus retusus  Chinese Fringetree  GCJA03-2A
# 1       45.5        NaN              No Tree                 N/A  GCJA03-2A
# 2       70.0        NaN              No Tree                 N/A  GCJA03-2A
# 3       70.0        NaN              No Tree                 N/A  GCJA03-2A
# 4       52.0   Standard    Quercus palustris             Pin Oak  GCJA03-2A
#
#   construc_1          program_ar   status_gro
# 0  Package-1  Right of Way (ROW)  Constructed
# 1  Package-1  Right of Way (ROW)  Constructed
# 2  Package-1  Right of Way (ROW)  Constructed
# 3  Package-1  Right of Way (ROW)  Constructed
# 4  Package-1  Right of Way (ROW)  Constructed
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   the_geom    1000 non-null   object
#  1   asset_id    1000 non-null   object
#  2   gi_id       1000 non-null   object
#  3   dep_contra  1000 non-null   object
#  4   dep_cont_1  1000 non-null   object
#  5   row_onsite  1000 non-null   object
#  6   project_na  1000 non-null   object
#  7   asset_type  1000 non-null   object
#  8   status      1000 non-null   object
#  9   asset_x_co  1000 non-null   object
#  10  asset_y_co  1000 non-null   object
#  11  borough     1000 non-null   object
#  12  sewer_type  1000 non-null   object
#  13  outfall     1000 non-null   object
#  14  nyc_waters  1000 non-null   object
#  15  bbl         1000 non-null   object
#  16  secondary_  1000 non-null   object
#  17  community_  1000 non-null   object
#  18  city_counc  1000 non-null   object
#  19  assembly_d  1000 non-null   object
#  20  asset_leng  1000 non-null   object
#  21  asset_widt  1000 non-null   object
#  22  asset_area  1000 non-null   object
#  23  gi_feature  900 non-null    object
#  24  tree_latin  994 non-null    object
#  25  tree_commo  994 non-null    object
#  26  constructi  994 non-null    object
#  27  construc_1  994 non-null    object
#  28  program_ar  1000 non-null   object
#  29  status_gro  1000 non-null   object
# dtypes: object(30)
# memory usage: 234.5+ KB

# %% [markdown]
# Example with the QUERY parameter.
#
# When querying all records, be sure to set the `limit` parameter to a value large enough to exceed the total number of records in your dataset. If the `limit` value is set to exactly the same number as the records returned, you likely haven’t retrieved all the data. To avoid this, choose a `limit` that is larger than the dataset’s total size.

# %%
# SoQL implementation with sodapy
# SoQL query string below:
# retrieve all columns and limit our records to 100

# green infrastructure dataset identifier
socrata_dataset_identifier = 'bs59-f3nu'

query = """
    SELECT *
    LIMIT 100
"""

# returned as JSON from API / converted to Python list of dictionaries by sodapy
# notice the query parameter
results = client.get(socrata_dataset_identifier, query=query)

# convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# sanity check
print(f'shape of data: {results_df.shape}')
results_df.head()
# Out:
# shape of data: (100, 30)
#                                             the_geom asset_id gi_id  \
# 0  {'type': 'Point', 'coordinates': [-73.81167623...  94002.0    1A
# 1  {'type': 'Point', 'coordinates': [-73.81228577...  94012.0  GS6A
# 2  {'type': 'Point', 'coordinates': [-73.81223444...  94017.0  GS8C
# 3  {'type': 'Point', 'coordinates': [-73.81205974...  94019.0  GS8E
# 4  {'type': 'Point', 'coordinates': [-73.81310191...  94021.0   10A
#
#   dep_contra dep_cont_1 row_onsite           project_na asset_type  \
# 0  GQJA03-02          2        ROW  DDC JAM-003 Phase 2       ROWB
# 1  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 2  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 3  GQJA03-02          2        ROW  DDC JAM-003 Phase 2      ROWGS
# 4  GQJA03-02          2        ROW  DDC JAM-003 Phase 2       ROWB
#
#                            status     asset_x_co  ... asset_leng asset_widt  \
# 0  Constructed (Full Maintenance)  1036475.27735  ...       17.0        5.0
# 1  Constructed (Full Maintenance)  1036305.46107  ...       13.0        3.5
# 2  Constructed (Full Maintenance)  1036319.11813  ...       20.0        3.5
# 3  Constructed (Full Maintenance)  1036367.52667  ...       20.0        3.5
# 4  Constructed (Full Maintenance)  1036078.81888  ...       13.0        4.0
#
#   asset_area gi_feature           tree_latin          tree_commo constructi  \
# 0       85.0   Standard  Chionanthus retusus  Chinese Fringetree  GCJA03-2A
# 1       45.5        NaN              No Tree                 N/A  GCJA03-2A
# 2       70.0        NaN              No Tree                 N/A  GCJA03-2A
# 3       70.0        NaN              No Tree                 N/A  GCJA03-2A
# 4       52.0   Standard    Quercus palustris             Pin Oak  GCJA03-2A
#
#   construc_1          program_ar   status_gro
# 0  Package-1  Right of Way (ROW)  Constructed
# 1  Package-1  Right of Way (ROW)  Constructed
# 2  Package-1  Right of Way (ROW)  Constructed
# 3  Package-1  Right of Way (ROW)  Constructed
# 4  Package-1  Right of Way (ROW)  Constructed
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 5.2  Discovery API
# Socrata's [Discovery API](https://dev.socrata.com/docs/other/discovery#?route=overview).

# %% [markdown]
# In Sodapy, we use the `.datasets()` method: Returns the list of datasets associated with a particular domain.
# WARNING: Large limits (>1000) will return megabytes of data, which can be slow on low-bandwidth networks, and is also a lot of data to hold in memory. This method performs a get request on these type of URLs: https://data.cityofnewyork.us/api/catalog/v1.

# %% [markdown]
# ### Using Socrata API URL

# %%
# Discovery API
url = 'https://api.us.socrata.com/api/catalog/v1?search_context=data.ny.gov'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json() 

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['results', 'resultSetSize', 'timings', 'warnings'])

# %%
# preview results key, first element
data_dict['results'][0]
# Out:
# {'resource': {'name': 'Lottery Cash 4 Life Winning Numbers: Beginning 2014',
#   'id': 'kwxv-fwze',
#   'resource_name': None,
#   'parent_fxf': [],
#   'description': 'Go to http://on.ny.gov/1xRIvPz on the New York Lottery website for past Cash 4 Life results and payouts.',
#   'attribution': 'New York State Gaming Commission',
#   'attribution_link': 'http://nylottery.ny.gov/wps/portal/Home/Lottery/home/your+lottery/drawing+results/drawingresults_cash4life',
#   'contact_email': 'opendata@its.ny.gov',
#   'type': 'dataset',
#   'updatedAt': '2024-12-02T11:05:05.000Z',
#   'createdAt': '2014-06-17T19:47:54.000Z',
#   'metadata_updated_at': '2024-12-02T11:05:04.000Z',
#   'data_updated_at': '2024-12-02T11:05:05.000Z',
#   'page_views': {'page_views_last_week': 482,
#    'page_views_last_month': 2482,
#    'page_views_total': 5932845,
#    'page_views_last_week_log': 8.915879378835772,
#    'page_views_last_month_log': 11.27786854617684,
#    'page_views_total_log': 22.50029290430145},
#   'columns_name': ['Draw Date', 'Cash Ball', 'Winning Numbers'],
#   'columns_field_name': ['draw_date', 'cash_ball', 'winning_numbers'],
#   'columns_datatype': ['Calendar date', 'Text', 'Text'],
#   'columns_description': ['Draw date', 'Cash ball', 'Winning numbers'],
#   'columns_format': [{'view': 'date', 'align': 'center'},
#    {'align': 'center'},
#    {'align': 'center'}],
#   'download_count': 230847,
#   'provenance': 'official',
#   'lens_view_type': 'tabular',
#   'lens_display_type': 'table',
#   'locked': False,
#   'blob_mime_type': None,
#   'hide_from_data_json': False,
#   'publication_date': '2021-04-27T14:13:45.000Z'},
#  'classification': {'categories': [],
#   'tags': [],
#   'domain_category': 'Government & Finance',
#   'domain_tags': ['cash 4 life', 'new york lottery', 'results', 'winning'],
#   'domain_metadata': [{'key': 'Common-Core_Publisher',
#     'value': 'State of New York'},
#    {'key': 'Common-Core_Contact-Name', 'value': 'Open Data NY'},
#    {'key': 'Common-Core_Contact-Email', 'value': 'opendata@its.ny.gov'},
#    {'key': 'Additional-Resources_See-Also',
#     'value': 'http://www.gaming.ny.gov/'},
#    {'key': 'Dataset-Summary_Dataset-Owner',
#     'value': 'New York State Gaming Commission'},
#    {'key': 'Dataset-Summary_Contact-Information',
#     'value': 'Info@gaming.ny.gov'},
#    {'key': 'Dataset-Summary_Granularity', 'value': 'By draw'},
#    {'key': 'Dataset-Summary_Coverage', 'value': 'Statewide'},
#    {'key': 'Dataset-Summary_Data-Frequency',
#     'value': 'Daily beginning 7/1/19; twice weekly previously'},
#    {'key': 'Dataset-Summary_Posting-Frequency', 'value': 'Daily'},
#    {'key': 'Dataset-Summary_Organization', 'value': 'The New York Lottery'},
#    {'key': 'Dataset-Summary_Time-Period', 'value': 'Beginning 6/16/2014'},
#    {'key': 'Dataset-Information_Agency',
#     'value': 'Gaming Commission, New York State'},
#    {'key': 'Notes_Notes',
#     'value': "The information contained on these pages is believed to be accurate. In the event of a discrepancy between the information displayed on this Web site concerning winning numbers and payouts and the information contained in the official and certified files maintained by the New York Lottery's Drawing Unit, those maintained by the Drawing Unit shall prevail."}]},
#  'metadata': {'domain': 'data.ny.gov'},
#  'permalink': 'https://data.ny.gov/d/kwxv-fwze',
#  'link': 'https://data.ny.gov/Government-Finance/Lottery-Cash-4-Life-Winning-Numbers-Beginning-2014/kwxv-fwze',
#  'owner': {'id': 'xzik-pf59',
#   'user_type': 'interactive',
#   'display_name': 'NY Open Data'},
#  'creator': {'id': 'xzik-pf59',
#   'user_type': 'interactive',
#   'display_name': 'NY Open Data'}}

# %%
# convert into df
df = pd.DataFrame.from_records(data_dict['results'])

# sanity check
print(df.shape)
df.head()
# Out:
# (100, 8)
#                                             resource  \
# 0  {'name': 'Lottery Cash 4 Life Winning Numbers:...
# 1  {'name': 'For Hire Vehicles (FHV) - Active', '...
# 2  {'name': 'Civil Service List (Active)', 'id': ...
# 3  {'name': 'DOB Job Application Filings', 'id': ...
# 4  {'name': 'Medicaid Enrolled Provider Listing',...
#
#                                       classification  \
# 0  {'categories': [], 'tags': [], 'domain_categor...
# 1  {'categories': [], 'tags': [], 'domain_categor...
# 2  {'categories': [], 'tags': [], 'domain_categor...
# 3  {'categories': [], 'tags': [], 'domain_categor...
# 4  {'categories': [], 'tags': [], 'domain_categor...
#
#                               metadata  \
# 0            {'domain': 'data.ny.gov'}
# 1  {'domain': 'data.cityofnewyork.us'}
# 2  {'domain': 'data.cityofnewyork.us'}
# 3  {'domain': 'data.cityofnewyork.us'}
# 4     {'domain': 'health.data.ny.gov'}
#
#                                    permalink  \
# 0            https://data.ny.gov/d/kwxv-fwze
# 1  https://data.cityofnewyork.us/d/8wbx-tsch
# 2  https://data.cityofnewyork.us/d/vx8i-nprf
# 3  https://data.cityofnewyork.us/d/ic3t-wcy2
# 4     https://health.data.ny.gov/d/keti-qx5t
#
#                                                 link  \
# 0  https://data.ny.gov/Government-Finance/Lottery...
# 1  https://data.cityofnewyork.us/Transportation/F...
# 2  https://data.cityofnewyork.us/City-Government/...
# 3  https://data.cityofnewyork.us/Housing-Developm...
# 4  https://health.data.ny.gov/Health/Medicaid-Enr...
#
#                                                owner  \
# 0  {'id': 'xzik-pf59', 'user_type': 'interactive'...
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...
# 4  {'id': 's9j2-nqmr', 'user_type': 'interactive'...
#
#                                              creator preview_image_url
# 0  {'id': 'xzik-pf59', 'user_type': 'interactive'...               NaN
# 1  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 2  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 3  {'id': '5fuc-pqz2', 'user_type': 'interactive'...               NaN
# 4  {'id': 's9j2-nqmr', 'user_type': 'interactive'...               NaN

# %% [markdown]
# This is not our final dataframe that contains our data in a tabular format. Our information most likely is located in the `resource` column, but let's confirm.

# %% [markdown]
# Briefly review the other keys.

# %%
# first element in our results list, preview resources key
data_dict['results'][0]['resource']
# Out:
# {'name': 'Lottery Cash 4 Life Winning Numbers: Beginning 2014',
#  'id': 'kwxv-fwze',
#  'resource_name': None,
#  'parent_fxf': [],
#  'description': 'Go to http://on.ny.gov/1xRIvPz on the New York Lottery website for past Cash 4 Life results and payouts.',
#  'attribution': 'New York State Gaming Commission',
#  'attribution_link': 'http://nylottery.ny.gov/wps/portal/Home/Lottery/home/your+lottery/drawing+results/drawingresults_cash4life',
#  'contact_email': 'opendata@its.ny.gov',
#  'type': 'dataset',
#  'updatedAt': '2024-12-02T11:05:05.000Z',
#  'createdAt': '2014-06-17T19:47:54.000Z',
#  'metadata_updated_at': '2024-12-02T11:05:04.000Z',
#  'data_updated_at': '2024-12-02T11:05:05.000Z',
#  'page_views': {'page_views_last_week': 482,
#   'page_views_last_month': 2482,
#   'page_views_total': 5932845,
#   'page_views_last_week_log': 8.915879378835772,
#   'page_views_last_month_log': 11.27786854617684,
#   'page_views_total_log': 22.50029290430145},
#  'columns_name': ['Draw Date', 'Cash Ball', 'Winning Numbers'],
#  'columns_field_name': ['draw_date', 'cash_ball', 'winning_numbers'],
#  'columns_datatype': ['Calendar date', 'Text', 'Text'],
#  'columns_description': ['Draw date', 'Cash ball', 'Winning numbers'],
#  'columns_format': [{'view': 'date', 'align': 'center'},
#   {'align': 'center'},
#   {'align': 'center'}],
#  'download_count': 230847,
#  'provenance': 'official',
#  'lens_view_type': 'tabular',
#  'lens_display_type': 'table',
#  'locked': False,
#  'blob_mime_type': None,
#  'hide_from_data_json': False,
#  'publication_date': '2021-04-27T14:13:45.000Z'}

# %%
# first element in our results list, preview classification key
data_dict['results'][0]['classification']
# Out:
# {'categories': [],
#  'tags': [],
#  'domain_category': 'Government & Finance',
#  'domain_tags': ['cash 4 life', 'new york lottery', 'results', 'winning'],
#  'domain_metadata': [{'key': 'Common-Core_Publisher',
#    'value': 'State of New York'},
#   {'key': 'Common-Core_Contact-Name', 'value': 'Open Data NY'},
#   {'key': 'Common-Core_Contact-Email', 'value': 'opendata@its.ny.gov'},
#   {'key': 'Additional-Resources_See-Also',
#    'value': 'http://www.gaming.ny.gov/'},
#   {'key': 'Dataset-Summary_Dataset-Owner',
#    'value': 'New York State Gaming Commission'},
#   {'key': 'Dataset-Summary_Contact-Information',
#    'value': 'Info@gaming.ny.gov'},
#   {'key': 'Dataset-Summary_Granularity', 'value': 'By draw'},
#   {'key': 'Dataset-Summary_Coverage', 'value': 'Statewide'},
#   {'key': 'Dataset-Summary_Data-Frequency',
#    'value': 'Daily beginning 7/1/19; twice weekly previously'},
#   {'key': 'Dataset-Summary_Posting-Frequency', 'value': 'Daily'},
#   {'key': 'Dataset-Summary_Organization', 'value': 'The New York Lottery'},
#   {'key': 'Dataset-Summary_Time-Period', 'value': 'Beginning 6/16/2014'},
#   {'key': 'Dataset-Information_Agency',
#    'value': 'Gaming Commission, New York State'},
#   {'key': 'Notes_Notes',
#    'value': "The information contained on these pages is believed to be accurate. In the event of a discrepancy between the information displayed on this Web site concerning winning numbers and payouts and the information contained in the official and certified files maintained by the New York Lottery's Drawing Unit, those maintained by the Drawing Unit shall prevail."}]}

# %%
# first element in our results list, preview metadata key
data_dict['results'][0]['metadata']
# Out:
# {'domain': 'data.ny.gov'}

# %%
# first element in our results list, preview permalink key
data_dict['results'][0]['permalink']
# Out:
# 'https://data.ny.gov/d/kwxv-fwze'

# %%
# first element in our results list, preview link key
data_dict['results'][0]['link']
# Out:
# 'https://data.ny.gov/Government-Finance/Lottery-Cash-4-Life-Winning-Numbers-Beginning-2014/kwxv-fwze'

# %%
# first element in our results list, preview owner key
data_dict['results'][0]['owner']
# Out:
# {'id': 'xzik-pf59', 'user_type': 'interactive', 'display_name': 'NY Open Data'}

# %%
# first element in our results list, preview creator key
data_dict['results'][0]['creator']
# Out:
# {'id': 'xzik-pf59', 'user_type': 'interactive', 'display_name': 'NY Open Data'}

# %% [markdown]
# After confirming data is in our resource key, let's unnest these values.

# %%
# retrieve information in the resource key
df['resource']
# Out:
# 0     {'name': 'Lottery Cash 4 Life Winning Numbers:...
# 1     {'name': 'For Hire Vehicles (FHV) - Active', '...
# 2     {'name': 'Civil Service List (Active)', 'id': ...
# 3     {'name': 'DOB Job Application Filings', 'id': ...
# 4     {'name': 'Medicaid Enrolled Provider Listing',...
#                             ...
# 95    {'name': 'Lottery Pick 10 Winning Numbers: Beg...
# 96    {'name': 'Street Hail Livery (SHL) Permits', '...
# 97    {'name': 'NYPD Complaint Data Current (Year To...
# 98    {'name': 'Index Crimes by County and Agency: B...
# 99    {'name': 'TLC Approved LabCorp Patient Service...
# Name: resource, Length: 100, dtype: object

# %%
# convert to a dataframe
df = pd.DataFrame.from_records(df['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (100, 27)
#                                                 name         id resource_name  \
# 0  Lottery Cash 4 Life Winning Numbers: Beginning...  kwxv-fwze          None
# 1                   For Hire Vehicles (FHV) - Active  8wbx-tsch          None
# 2                        Civil Service List (Active)  vx8i-nprf          None
# 3                        DOB Job Application Filings  ic3t-wcy2          None
# 4                 Medicaid Enrolled Provider Listing  keti-qx5t          None
#
#   parent_fxf                                        description  \
# 0         []  Go to http://on.ny.gov/1xRIvPz on the New York...
# 1         []  <b>PLEASE NOTE:</b> This dataset, which includ...
# 2         []  A Civil Service List consists of all candidate...
# 3         []  This dataset contains all job applications sub...
# 4         []  <b>Revalidation disclaimer</b>:  The next anti...
#
#                                          attribution  \
# 0                   New York State Gaming Commission
# 1                Taxi and Limousine Commission (TLC)
# 2  Department of Citywide Administrative Services...
# 3                      Department of Buildings (DOB)
# 4                New York State Department of Health
#
#                                     attribution_link        contact_email  \
# 0  http://nylottery.ny.gov/wps/portal/Home/Lotter...  opendata@its.ny.gov
# 1                                               None                 None
# 2                                               None                 None
# 3                                               None                 None
# 4  https://www.emedny.org/info/ProviderEnrollment...                 None
#
#       type                 updatedAt  ...  \
# 0  dataset  2024-12-02T11:05:05.000Z  ...
# 1  dataset  2024-12-02T19:55:58.000Z  ...
# 2  dataset  2024-12-02T14:16:52.000Z  ...
# 3  dataset  2024-12-02T21:02:15.000Z  ...
# 4  dataset  2024-12-02T19:12:09.000Z  ...
#
#                                  columns_description  \
# 0            [Draw date, Cash ball, Winning numbers]
# 1  [Vehicle VIN Number, Base Website, Base Teleph...
# 2  [A candidate’s last name as it appears on thei...
# 3  [Street Name where Property is located, Longit...
# 4  [Longitude related to the service address for ...
#
#                                       columns_format download_count  \
# 0  [{'view': 'date', 'align': 'center'}, {'align'...         230847
# 1  [{'displayStyle': 'plain', 'align': 'left'}, {...              0
# 2  [{'displayStyle': 'plain', 'align': 'left'}, {...              0
# 3  [{'align': 'right'}, {'align': 'right'}, {'vie...              0
# 4  [{}, {}, {'align': 'left'}, {}, {}, {'view': '...              0
#
#   provenance lens_view_type lens_display_type locked blob_mime_type  \
# 0   official        tabular             table  False           None
# 1   official        tabular             table  False           None
# 2   official        tabular             table  False           None
# 3   official        tabular             table  False           None
# 4   official        tabular             table  False           None
#
#   hide_from_data_json          publication_date
# 0               False  2021-04-27T14:13:45.000Z
# 1               False  2021-04-05T13:20:47.000Z
# 2               False  2024-01-12T16:15:05.000Z
# 3               False  2020-06-22T18:23:35.000Z
# 4               False  2020-12-28T16:03:15.000Z
#
# [5 rows x 27 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 100 non-null    object
#  1   id                   100 non-null    object
#  2   resource_name        1 non-null      object
#  3   parent_fxf           100 non-null    object
#  4   description          100 non-null    object
#  5   attribution          89 non-null     object
#  6   attribution_link     51 non-null     object
#  7   contact_email        20 non-null     object
#  8   type                 100 non-null    object
#  9   updatedAt            100 non-null    object
#  10  createdAt            100 non-null    object
#  11  metadata_updated_at  100 non-null    object
#  12  data_updated_at      100 non-null    object
#  13  page_views           100 non-null    object
#  14  columns_name         100 non-null    object
#  15  columns_field_name   100 non-null    object
#  16  columns_datatype     100 non-null    object
#  17  columns_description  100 non-null    object
#  18  columns_format       100 non-null    object
#  19  download_count       100 non-null    int64
#  20  provenance           100 non-null    object
#  21  lens_view_type       100 non-null    object
#  22  lens_display_type    100 non-null    object
#  23  locked               100 non-null    bool
#  24  blob_mime_type       3 non-null      object
#  25  hide_from_data_json  100 non-null    bool
#  26  publication_date     100 non-null    object
# dtypes: bool(2), int64(1), object(24)
# memory usage: 19.9+ KB

# %%
# preview values
df.head(3).T
# Out:
#                                                                      0  \
# name                 Lottery Cash 4 Life Winning Numbers: Beginning...
# id                                                           kwxv-fwze
# resource_name                                                     None
# parent_fxf                                                          []
# description          Go to http://on.ny.gov/1xRIvPz on the New York...
# attribution                           New York State Gaming Commission
# attribution_link     http://nylottery.ny.gov/wps/portal/Home/Lotter...
# contact_email                                      opendata@its.ny.gov
# type                                                           dataset
# updatedAt                                     2024-12-02T11:05:05.000Z
# createdAt                                     2014-06-17T19:47:54.000Z
# metadata_updated_at                           2024-12-02T11:05:04.000Z
# data_updated_at                               2024-12-02T11:05:05.000Z
# page_views           {'page_views_last_week': 482, 'page_views_last...
# columns_name                   [Draw Date, Cash Ball, Winning Numbers]
# columns_field_name             [draw_date, cash_ball, winning_numbers]
# columns_datatype                           [Calendar date, Text, Text]
# columns_description            [Draw date, Cash ball, Winning numbers]
# columns_format       [{'view': 'date', 'align': 'center'}, {'align'...
# download_count                                                  230847
# provenance                                                    official
# lens_view_type                                                 tabular
# lens_display_type                                                table
# locked                                                           False
# blob_mime_type                                                    None
# hide_from_data_json                                              False
# publication_date                              2021-04-27T14:13:45.000Z
#
#                                                                      1  \
# name                                  For Hire Vehicles (FHV) - Active
# id                                                           8wbx-tsch
# resource_name                                                     None
# parent_fxf                                                          []
# description          <b>PLEASE NOTE:</b> This dataset, which includ...
# attribution                        Taxi and Limousine Commission (TLC)
# attribution_link                                                  None
# contact_email                                                     None
# type                                                           dataset
# updatedAt                                     2024-12-02T19:55:58.000Z
# createdAt                                     2015-07-16T17:33:32.000Z
# metadata_updated_at                           2022-09-06T21:05:32.000Z
# data_updated_at                               2024-12-02T19:55:58.000Z
# page_views           {'page_views_last_week': 2, 'page_views_last_m...
# columns_name         [Vehicle VIN Number, Website, Base Telephone N...
# columns_field_name   [vehicle_vin_number, website, base_telephone_n...
# columns_datatype     [Text, Text, Text, Text, Calendar date, Text, ...
# columns_description  [Vehicle VIN Number, Base Website, Base Teleph...
# columns_format       [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                       0
# provenance                                                    official
# lens_view_type                                                 tabular
# lens_display_type                                                table
# locked                                                           False
# blob_mime_type                                                    None
# hide_from_data_json                                              False
# publication_date                              2021-04-05T13:20:47.000Z
#
#                                                                      2
# name                                       Civil Service List (Active)
# id                                                           vx8i-nprf
# resource_name                                                     None
# parent_fxf                                                          []
# description          A Civil Service List consists of all candidate...
# attribution          Department of Citywide Administrative Services...
# attribution_link                                                  None
# contact_email                                                     None
# type                                                           dataset
# updatedAt                                     2024-12-02T14:16:52.000Z
# createdAt                                     2016-06-14T21:12:15.000Z
# metadata_updated_at                           2024-05-14T14:26:52.000Z
# data_updated_at                               2024-12-02T14:16:52.000Z
# page_views           {'page_views_last_week': 0, 'page_views_last_m...
# columns_name         [Last Name, First Name, List No, Anniversary D...
# columns_field_name   [last_name, first_name, list_no, anniversary_d...
# columns_datatype     [Text, Text, Number, Calendar date, Text, Text...
# columns_description  [A candidate’s last name as it appears on thei...
# columns_format       [{'displayStyle': 'plain', 'align': 'left'}, {...
# download_count                                                       0
# provenance                                                    official
# lens_view_type                                                 tabular
# lens_display_type                                                table
# locked                                                           False
# blob_mime_type                                                    None
# hide_from_data_json                                              False
# publication_date                              2024-01-12T16:15:05.000Z

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

# call sodapy's datasets method
datasets = client.datasets()

# sanity checks
print(f'object type: {type(datasets)}')
print(f'Number of datasets on NYC Open Data: {len(datasets):,}.')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# object type: <class 'list'>
# Number of datasets on NYC Open Data: 3,237.

# %%
# review type about first dataset
print(type(datasets[0]))
# Out:
# <class 'dict'>

# %%
# review information about keys
datasets[0].keys()
# Out:
# dict_keys(['resource', 'classification', 'metadata', 'permalink', 'link', 'owner', 'creator'])

# %%
# review information about resource key
resources = datasets[0]['resource'].items()

for key, value in resources:
    print(f'{key}: {value}\n')
# Out:
# name: For Hire Vehicles (FHV) - Active
#
# id: 8wbx-tsch
#
# resource_name: None
#
# parent_fxf: []
#
# description: <b>PLEASE NOTE:</b> This dataset, which includes all TLC licensed for-hire vehicles which are in good standing and able to drive, is updated every day in the evening between 4-7pm. Please check the 'Last Update Date' field to make sure the list has updated successfully. 'Last Update Date'  should show either today or yesterday's date, depending on the time of day. If the list is outdated, please download the most recent list from the link below.
# http://www1.nyc.gov/assets/tlc/downloads/datasets/tlc_for_hire_vehicle_active_and_inactive.csv
#
# TLC authorized For-Hire vehicles that are active. This list is accurate to the date and time represented in the Last Date Updated and Last Time Updated fields. For inquiries about the contents of this dataset, please email licensinginquiries@tlc.nyc.gov.
#
# attribution: Taxi and Limousine Commission (TLC)
#
# attribution_link: None
#
# contact_email: None
#
# type: dataset
#
# updatedAt: 2024-12-02T19:55:58.000Z
#
# createdAt: 2015-07-16T17:33:32.000Z
#
# metadata_updated_at: 2022-09-06T21:05:32.000Z
#
# data_updated_at: 2024-12-02T19:55:58.000Z
#
# page_views: {'page_views_last_week': 6965, 'page_views_last_month': 30865, 'page_views_total': 2920779, 'page_views_last_week_log': 12.766114757586724, 'page_views_last_month_log': 14.913730912257195, 'page_views_total_log': 21.47792226440942}
#
# columns_name: ['Vehicle VIN Number', 'Website', 'Base Telephone Number', 'Base Name', 'Certification Date', 'Permit License Number', 'Expiration Date', 'Name', 'Vehicle License Number', 'Base Number', 'Vehicle Year', 'Order Date', 'Base Type', 'Hack Up Date', 'Reason', 'Base Address', 'DMV License Plate Number', 'Active', 'VEH', 'License Type', 'Last Time Updated', 'Wheelchair Accessible', 'Last Date Updated']
#
# columns_field_name: ['vehicle_vin_number', 'website', 'base_telephone_number', 'base_name', 'certification_date', 'permit_license_number', 'expiration_date', 'name', 'vehicle_license_number', 'base_number', 'vehicle_year', 'order_date', 'base_type', 'hack_up_date', 'reason', 'base_address', 'dmv_license_plate_number', 'active', 'veh', 'license_type', 'last_time_updated', 'wheelchair_accessible', 'last_date_updated']
#
# columns_datatype: ['Text', 'Text', 'Text', 'Text', 'Calendar date', 'Text', 'Calendar date', 'Text', 'Text', 'Text', 'Number', 'Calendar date', 'Text', 'Calendar date', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Text', 'Calendar date']
#
# columns_description: ['Vehicle VIN Number', 'Base Website', 'Base Telephone NumberBase Telephone Number', 'Base Name', 'Certification Date', 'Permit License Number', 'Expiration Date', 'Owner Name\n', 'FHV Vehicle License Number', 'Base Number', 'Vehicle Year', 'Date Suspension ordered\n', 'Base Type', 'Hack Up Date', 'Reason Code A,B,C or G\n', 'Base Address', 'DMV License Plate Number', 'Permit active or not\n', 'Hybrid vehicle indicator\n', 'TLC License Type\n', 'Last Time Updated', 'Wheelchair Accessible Indicator\n', 'Last Date Updated']
#
# columns_format: [{'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'precisionStyle': 'standard', 'noCommas': 'true', 'align': 'right'}, {'view': 'date_time', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'displayStyle': 'plain', 'align': 'left'}, {'view': 'date', 'align': 'left'}]
#
# download_count: 531606
#
# provenance: official
#
# lens_view_type: tabular
#
# lens_display_type: table
#
# locked: False
#
# blob_mime_type: None
#
# hide_from_data_json: False
#
# publication_date: 2021-04-05T13:20:47.000Z

# %%
# green infrastructure id on website URL
id_on_website = 'spjh-pz7h'

# get the list of datasets once
datasets = client.datasets()

# loop through the datasets to find the one with the matching identifier
for idx, dataset in enumerate(datasets):
    if dataset['resource']['id'] == id_on_website:
        print('We found the Green Infrastructure dataset!')
        print(f'Index is: {idx}')
        
        dataset_index = idx
        break
# Out:
# We found the Green Infrastructure dataset!
# Index is: 196

# %%
data = datasets[dataset_index]['resource']
df = pd.DataFrame([data])

df.head()
# Out:
#                        name         id resource_name parent_fxf  \
# 0  DEP Green Infrastructure  spjh-pz7h          None         []
#
#                                          description  \
# 0  NYC Green Infrastructure Program initiatives. ...
#
#                                     attribution attribution_link  \
# 0  Department of Environmental Protection (DEP)             None
#
#   contact_email type                 updatedAt  ... columns_description  \
# 0          None  map  2024-11-06T14:58:19.000Z  ...                  []
#
#   columns_format download_count provenance lens_view_type lens_display_type  \
# 0             []          27796   official            geo               map
#
#   locked   blob_mime_type hide_from_data_json          publication_date
# 0  False  application/zip               False  2017-08-31T20:33:51.000Z
#
# [1 rows x 27 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1 non-null      object
#  1   id                   1 non-null      object
#  2   resource_name        0 non-null      object
#  3   parent_fxf           1 non-null      object
#  4   description          1 non-null      object
#  5   attribution          1 non-null      object
#  6   attribution_link     0 non-null      object
#  7   contact_email        0 non-null      object
#  8   type                 1 non-null      object
#  9   updatedAt            1 non-null      object
#  10  createdAt            1 non-null      object
#  11  metadata_updated_at  1 non-null      object
#  12  data_updated_at      1 non-null      object
#  13  page_views           1 non-null      object
#  14  columns_name         1 non-null      object
#  15  columns_field_name   1 non-null      object
#  16  columns_datatype     1 non-null      object
#  17  columns_description  1 non-null      object
#  18  columns_format       1 non-null      object
#  19  download_count       1 non-null      int64
#  20  provenance           1 non-null      object
#  21  lens_view_type       1 non-null      object
#  22  lens_display_type    1 non-null      object
#  23  locked               1 non-null      bool
#  24  blob_mime_type       1 non-null      object
#  25  hide_from_data_json  1 non-null      bool
#  26  publication_date     1 non-null      object
# dtypes: bool(2), int64(1), object(24)
# memory usage: 330.0+ bytes

# %%
# alternatively: normalize JSON, unnest values
df = pd.json_normalize(datasets[dataset_index]['resource'])

# sanity check
print(df.shape)
df.head()
# Out:
# (1, 32)
#                        name         id resource_name parent_fxf  \
# 0  DEP Green Infrastructure  spjh-pz7h          None         []
#
#                                          description  \
# 0  NYC Green Infrastructure Program initiatives. ...
#
#                                     attribution attribution_link  \
# 0  Department of Environmental Protection (DEP)             None
#
#   contact_email type                 updatedAt  ... locked   blob_mime_type  \
# 0          None  map  2024-11-06T14:58:19.000Z  ...  False  application/zip
#
#   hide_from_data_json          publication_date  \
# 0               False  2017-08-31T20:33:51.000Z
#
#   page_views.page_views_last_week page_views.page_views_last_month  \
# 0                             112                              512
#
#   page_views.page_views_total page_views.page_views_last_week_log  \
# 0                       19241                            6.820179
#
#    page_views.page_views_last_month_log page_views.page_views_total_log
# 0                              9.002815                       14.231971
#
# [1 rows x 32 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   name                                  1 non-null      object
#  1   id                                    1 non-null      object
#  2   resource_name                         0 non-null      object
#  3   parent_fxf                            1 non-null      object
#  4   description                           1 non-null      object
#  5   attribution                           1 non-null      object
#  6   attribution_link                      0 non-null      object
#  7   contact_email                         0 non-null      object
#  8   type                                  1 non-null      object
#  9   updatedAt                             1 non-null      object
#  10  createdAt                             1 non-null      object
#  11  metadata_updated_at                   1 non-null      object
#  12  data_updated_at                       1 non-null      object
#  13  columns_name                          1 non-null      object
#  14  columns_field_name                    1 non-null      object
#  15  columns_datatype                      1 non-null      object
#  16  columns_description                   1 non-null      object
#  17  columns_format                        1 non-null      object
#  18  download_count                        1 non-null      int64
#  19  provenance                            1 non-null      object
#  20  lens_view_type                        1 non-null      object
#  21  lens_display_type                     1 non-null      object
#  22  locked                                1 non-null      bool
#  23  blob_mime_type                        1 non-null      object
#  24  hide_from_data_json                   1 non-null      bool
#  25  publication_date                      1 non-null      object
#  26  page_views.page_views_last_week       1 non-null      int64
#  27  page_views.page_views_last_month      1 non-null      int64
#  28  page_views.page_views_total           1 non-null      int64
#  29  page_views.page_views_last_week_log   1 non-null      float64
#  30  page_views.page_views_last_month_log  1 non-null      float64
#  31  page_views.page_views_total_log       1 non-null      float64
# dtypes: bool(2), float64(3), int64(4), object(23)
# memory usage: 370.0+ bytes

# %%
# preview values
df.T
# Out:
#                                                                                       0
# name                                                           DEP Green Infrastructure
# id                                                                            spjh-pz7h
# resource_name                                                                      None
# parent_fxf                                                                           []
# description                           NYC Green Infrastructure Program initiatives. ...
# attribution                                Department of Environmental Protection (DEP)
# attribution_link                                                                   None
# contact_email                                                                      None
# type                                                                                map
# updatedAt                                                      2024-11-06T14:58:19.000Z
# createdAt                                                      2017-08-31T20:33:51.000Z
# metadata_updated_at                                            2024-11-06T14:58:19.000Z
# data_updated_at                                                2024-11-06T14:58:02.000Z
# columns_name                                                                         []
# columns_field_name                                                                   []
# columns_datatype                                                                     []
# columns_description                                                                  []
# columns_format                                                                       []
# download_count                                                                    27796
# provenance                                                                     official
# lens_view_type                                                                      geo
# lens_display_type                                                                   map
# locked                                                                            False
# blob_mime_type                                                          application/zip
# hide_from_data_json                                                               False
# publication_date                                               2017-08-31T20:33:51.000Z
# page_views.page_views_last_week                                                     112
# page_views.page_views_last_month                                                    512
# page_views.page_views_total                                                       19241
# page_views.page_views_last_week_log                                            6.820179
# page_views.page_views_last_month_log                                           9.002815
# page_views.page_views_total_log                                               14.231971

# %% [markdown]
# ## 5.3  Metadata API
# Socrata's [Metadata API](https://dev.socrata.com/docs/other/metadata#?route=overview).

# %% [markdown]
# In Sodapy, we use the `.get_metadata()` method: Retrieve the metadata for a particular dataset.

# %% [markdown]
# ### Using Socrata API URL

# %%
# Metadata API with 311 dataset
# https://dev.socrata.com/docs/other/metadata#?route=overview

# all datasets on NYC Open Data, and expand nested values
url = 'https://data.cityofnewyork.us/api/views/'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#           id                                              name assetType  \
# 0  6xyb-j5pk                          NYC Address Points (Map)       map
# 1  uf93-f8nk                                NYC Address Points   dataset
# 2  b7aj-ck5a  NYC Greenhouse Gas Emissions Municipal Inventory   dataset
# 3  3g6p-4u5s                         Building Footprints (Map)       map
# 4  u9wf-3gbt                     Building Footprints (P Layer)   dataset
#
#    averageRating         category   createdAt  \
# 0              0  City Government  1732652029
# 1              0  City Government  1732641922
# 2              0      Environment  1732116009
# 3              0  City Government  1731516162
# 4              0  City Government  1731513726
#
#                                          description  \
# 0  Address points were developed to supplement th...
# 1  Address points were developed to supplement th...
# 2  The Inventory of New York City Greenhouse Gas ...
# 3  Shapefile of footprint outlines of buildings i...
# 4  Shapefile of footprint outlines of buildings i...
#
#                 displayType  downloadCount  hideFromCatalog  ...  blobId  \
# 0  visualization_canvas_map              0            False  ...     NaN
# 1                     table             28            False  ...     NaN
# 2                     table             40            False  ...     NaN
# 3  visualization_canvas_map              1            False  ...     NaN
# 4                     table             22            False  ...     NaN
#
#    blobMimeType rowIdentifierColumnId  queryString  ratings  indexUpdatedAt  \
# 0           NaN                   NaN          NaN      NaN             NaN
# 1           NaN                   NaN          NaN      NaN             NaN
# 2           NaN                   NaN          NaN      NaN             NaN
# 3           NaN                   NaN          NaN      NaN             NaN
# 4           NaN                   NaN          NaN      NaN             NaN
#
#   childViews  iconUrl  previewImageId  disabledFeatureFlags
# 0        NaN      NaN             NaN                   NaN
# 1        NaN      NaN             NaN                   NaN
# 2        NaN      NaN             NaN                   NaN
# 3        NaN      NaN             NaN                   NaN
# 4        NaN      NaN             NaN                   NaN
#
# [5 rows x 51 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        3237 non-null   object
#  1   name                      3237 non-null   object
#  2   assetType                 3237 non-null   object
#  3   averageRating             3237 non-null   int64
#  4   category                  3137 non-null   object
#  5   createdAt                 3237 non-null   int64
#  6   description               3172 non-null   object
#  7   displayType               3237 non-null   object
#  8   downloadCount             3237 non-null   int64
#  9   hideFromCatalog           3237 non-null   bool
#  10  hideFromDataJson          3237 non-null   bool
#  11  locked                    3237 non-null   bool
#  12  modifyingViewUid          273 non-null    object
#  13  newBackend                3237 non-null   bool
#  14  numberOfComments          3237 non-null   int64
#  15  oid                       3237 non-null   int64
#  16  provenance                3237 non-null   object
#  17  publicationAppendEnabled  3237 non-null   bool
#  18  publicationDate           3212 non-null   float64
#  19  publicationGroup          3237 non-null   int64
#  20  publicationStage          3237 non-null   object
#  21  rowsUpdatedAt             3060 non-null   float64
#  22  rowsUpdatedBy             2798 non-null   object
#  23  tableId                   3237 non-null   int64
#  24  totalTimesRated           3237 non-null   int64
#  25  viewCount                 3237 non-null   int64
#  26  viewLastModified          3237 non-null   int64
#  27  viewType                  3237 non-null   object
#  28  approvals                 3237 non-null   object
#  29  clientContext             3237 non-null   object
#  30  grants                    3237 non-null   object
#  31  metadata                  3237 non-null   object
#  32  owner                     3237 non-null   object
#  33  rights                    3237 non-null   object
#  34  tableAuthor               3237 non-null   object
#  35  flags                     3237 non-null   object
#  36  tags                      2453 non-null   object
#  37  locale                    383 non-null    object
#  38  rowClass                  1661 non-null   object
#  39  blobFilename              202 non-null    object
#  40  blobFileSize              202 non-null    float64
#  41  blobId                    202 non-null    object
#  42  blobMimeType              202 non-null    object
#  43  rowIdentifierColumnId     57 non-null     float64
#  44  queryString               1 non-null      object
#  45  ratings                   24 non-null     object
#  46  indexUpdatedAt            1785 non-null   float64
#  47  childViews                35 non-null     object
#  48  iconUrl                   41 non-null     object
#  49  previewImageId            110 non-null    object
#  50  disabledFeatureFlags      16 non-null     object
# dtypes: bool(5), float64(5), int64(10), object(31)
# memory usage: 1.2+ MB

# %%
# example of Discovery API with the 311 dataset
# instead of expanding nested columns, let's keep only top-level columns
url = 'https://data.cityofnewyork.us/api/views/erm2-nwe9'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json()  

# preview keys    
data_dict.keys()
# Out:
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'locked', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowIdentifierColumnId', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'clientContext', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
# convert to df
df = pd.DataFrame([data_dict])

df.head()
# Out:
#           id                                       name assetType attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present   dataset         311
#
#    averageRating         category   createdAt  \
# 0              0  Social Services  1318225937
#
#                                          description displayType  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...       table
#
#    downloadCount  ...                                      clientContext  \
# 0         444317  ...  {'clientContextVariables': [], 'inheritedVaria...
#
#                                              columns  \
# 0  [{'id': 585605889, 'name': 'Unique Key', 'data...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                                             metadata  \
# 0  {'rdfSubject': '0', 'rdfClass': '', 'jsonQuery...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                query  rights  \
# 0  {'orderBys': [{'ascending': False, 'expression...  [read]
#
#                                          tableAuthor  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                 tags  \
# 0  [311, 311 service requests, city government, s...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...
#
# [1 rows x 41 columns]

# %%
# view columns, notice the decrease in number of columns compared to the previous example
# some values are still nested
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1 non-null      object
#  1   name                      1 non-null      object
#  2   assetType                 1 non-null      object
#  3   attribution               1 non-null      object
#  4   averageRating             1 non-null      int64
#  5   category                  1 non-null      object
#  6   createdAt                 1 non-null      int64
#  7   description               1 non-null      object
#  8   displayType               1 non-null      object
#  9   downloadCount             1 non-null      int64
#  10  hideFromCatalog           1 non-null      bool
#  11  hideFromDataJson          1 non-null      bool
#  12  locked                    1 non-null      bool
#  13  newBackend                1 non-null      bool
#  14  numberOfComments          1 non-null      int64
#  15  oid                       1 non-null      int64
#  16  provenance                1 non-null      object
#  17  publicationAppendEnabled  1 non-null      bool
#  18  publicationDate           1 non-null      int64
#  19  publicationGroup          1 non-null      int64
#  20  publicationStage          1 non-null      object
#  21  rowClass                  1 non-null      object
#  22  rowIdentifierColumnId     1 non-null      int64
#  23  rowsUpdatedAt             1 non-null      int64
#  24  rowsUpdatedBy             1 non-null      object
#  25  tableId                   1 non-null      int64
#  26  totalTimesRated           1 non-null      int64
#  27  viewCount                 1 non-null      int64
#  28  viewLastModified          1 non-null      int64
#  29  viewType                  1 non-null      object
#  30  approvals                 1 non-null      object
#  31  clientContext             1 non-null      object
#  32  columns                   1 non-null      object
#  33  grants                    1 non-null      object
#  34  metadata                  1 non-null      object
#  35  owner                     1 non-null      object
#  36  query                     1 non-null      object
#  37  rights                    1 non-null      object
#  38  tableAuthor               1 non-null      object
#  39  tags                      1 non-null      object
#  40  flags                     1 non-null      object
# dtypes: bool(5), int64(13), object(23)
# memory usage: 421.0+ bytes

# %% [markdown]
# ### Using Sodapy

# %%
# source domain for NYC Open Data on Socrata
socrata_domain = 'data.cityofnewyork.us'

# dataset id for NYC 311 on NYC Open Data on Socrata
socrata_dataset_identifier = 'erm2-nwe9'

# initialize client
client = Socrata(
    socrata_domain,
    app_token=None,
    timeout=100
)

# similar to: 'https://data.cityofnewyork.us/api/views/metadata/v1/'
metadata = client.get_metadata(socrata_dataset_identifier)

metadata.keys()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# dict_keys(['id', 'name', 'assetType', 'attribution', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'locked', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowIdentifierColumnId', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'approvals', 'clientContext', 'columns', 'grants', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
# convert to df
df = pd.DataFrame([metadata])

# preview data
df.head()
# Out:
#           id                                       name assetType attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present   dataset         311
#
#    averageRating         category   createdAt  \
# 0              0  Social Services  1318225937
#
#                                          description displayType  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...       table
#
#    downloadCount  ...                                      clientContext  \
# 0         444317  ...  {'clientContextVariables': [], 'inheritedVaria...
#
#                                              columns  \
# 0  [{'id': 585605889, 'name': 'Unique Key', 'data...
#
#                                               grants  \
# 0  [{'inherited': False, 'type': 'viewer', 'flags...
#
#                                             metadata  \
# 0  {'rdfSubject': '0', 'rdfClass': '', 'jsonQuery...
#
#                                                owner  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                query  rights  \
# 0  {'orderBys': [{'ascending': False, 'expression...  [read]
#
#                                          tableAuthor  \
# 0  {'id': '5fuc-pqz2', 'displayName': 'NYC OpenDa...
#
#                                                 tags  \
# 0  [311, 311 service requests, city government, s...
#
#                                                flags
# 0  [default, ownerMayBeContacted, restorable, res...
#
# [1 rows x 41 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1 non-null      object
#  1   name                      1 non-null      object
#  2   assetType                 1 non-null      object
#  3   attribution               1 non-null      object
#  4   averageRating             1 non-null      int64
#  5   category                  1 non-null      object
#  6   createdAt                 1 non-null      int64
#  7   description               1 non-null      object
#  8   displayType               1 non-null      object
#  9   downloadCount             1 non-null      int64
#  10  hideFromCatalog           1 non-null      bool
#  11  hideFromDataJson          1 non-null      bool
#  12  locked                    1 non-null      bool
#  13  newBackend                1 non-null      bool
#  14  numberOfComments          1 non-null      int64
#  15  oid                       1 non-null      int64
#  16  provenance                1 non-null      object
#  17  publicationAppendEnabled  1 non-null      bool
#  18  publicationDate           1 non-null      int64
#  19  publicationGroup          1 non-null      int64
#  20  publicationStage          1 non-null      object
#  21  rowClass                  1 non-null      object
#  22  rowIdentifierColumnId     1 non-null      int64
#  23  rowsUpdatedAt             1 non-null      int64
#  24  rowsUpdatedBy             1 non-null      object
#  25  tableId                   1 non-null      int64
#  26  totalTimesRated           1 non-null      int64
#  27  viewCount                 1 non-null      int64
#  28  viewLastModified          1 non-null      int64
#  29  viewType                  1 non-null      object
#  30  approvals                 1 non-null      object
#  31  clientContext             1 non-null      object
#  32  columns                   1 non-null      object
#  33  grants                    1 non-null      object
#  34  metadata                  1 non-null      object
#  35  owner                     1 non-null      object
#  36  query                     1 non-null      object
#  37  rights                    1 non-null      object
#  38  tableAuthor               1 non-null      object
#  39  tags                      1 non-null      object
#  40  flags                     1 non-null      object
# dtypes: bool(5), int64(13), object(23)
# memory usage: 421.0+ bytes

# %%
# example of the Metadata API
# https://dev.socrata.com/docs/other/metadata#?route=overview

# all datasets on NYC Open Data, notice the metadata in the URL
url = 'https://data.cityofnewyork.us/api/views/metadata/v1/'
df = pd.read_json(url)

# preview data
df.head()
# Out:
#           id                                              name  \
# 0  6xyb-j5pk                          NYC Address Points (Map)
# 1  uf93-f8nk                                NYC Address Points
# 2  b7aj-ck5a  NYC Greenhouse Gas Emissions Municipal Inventory
# 3  3g6p-4u5s                         Building Footprints (Map)
# 4  u9wf-3gbt                     Building Footprints (P Layer)
#
#                                          attribution  \
# 0          Office of Technology and Innovation (OTI)
# 1          Office of Technology and Innovation (OTI)
# 2  Mayor's Office of Climate and Environmental Ju...
# 3          Office of Technology and Innovation (OTI)
# 4          Office of Technology and Innovation (OTI)
#
#                                      attributionLink         category  \
# 0                                               None  City Government
# 1                                               None  City Government
# 2  https://climate.cityofnewyork.us/initiatives/n...      Environment
# 3                                               None  City Government
# 4                                               None  City Government
#
#                   createdAt             dataUpdatedAt  \
# 0  2024-11-26T20:13:49+0000  2024-11-26T18:02:43+0000
# 1  2024-11-26T17:25:22+0000  2024-11-26T18:02:43+0000
# 2  2024-11-20T15:20:09+0000  2024-11-20T15:48:44+0000
# 3  2024-11-13T16:42:42+0000  2024-11-26T17:51:19+0000
# 4  2024-11-13T16:02:06+0000  2024-11-26T17:33:50+0000
#
#                                             dataUri  \
# 0  https://data.cityofnewyork.us/resource/6xyb-j5pk
# 1  https://data.cityofnewyork.us/resource/uf93-f8nk
# 2  https://data.cityofnewyork.us/resource/b7aj-ck5a
# 3  https://data.cityofnewyork.us/resource/3g6p-4u5s
# 4  https://data.cityofnewyork.us/resource/u9wf-3gbt
#
#                                          description                 domain  \
# 0  Address points were developed to supplement th...  data.cityofnewyork.us
# 1  Address points were developed to supplement th...  data.cityofnewyork.us
# 2  The Inventory of New York City Greenhouse Gas ...  data.cityofnewyork.us
# 3  Shapefile of footprint outlines of buildings i...  data.cityofnewyork.us
# 4  Shapefile of footprint outlines of buildings i...  data.cityofnewyork.us
#
#    ...  hideFromCatalog  hideFromDataJson  license         metadataUpdatedAt  \
# 0  ...            False             False     None  2024-11-26T20:14:56+0000
# 1  ...            False             False     None  2024-11-26T20:13:07+0000
# 2  ...            False             False     None  2024-11-20T15:49:27+0000
# 3  ...            False             False     None  2024-11-13T16:47:48+0000
# 4  ...            False             False     None  2024-11-26T17:32:07+0000
#
#   provenance                 updatedAt  \
# 0   OFFICIAL  2024-11-26T20:14:56+0000
# 1   OFFICIAL  2024-11-26T20:13:07+0000
# 2   OFFICIAL  2024-11-20T15:49:49+0000
# 3   OFFICIAL  2024-11-13T16:47:48+0000
# 4   OFFICIAL  2024-11-26T17:32:07+0000
#
#                                       webUri  \
# 0  https://data.cityofnewyork.us/d/6xyb-j5pk
# 1  https://data.cityofnewyork.us/d/uf93-f8nk
# 2  https://data.cityofnewyork.us/d/b7aj-ck5a
# 3  https://data.cityofnewyork.us/d/3g6p-4u5s
# 4  https://data.cityofnewyork.us/d/u9wf-3gbt
#
#                                            approvals  \
# 0  [{'reviewedAt': 1732652072, 'reviewedAutomatic...
# 1  [{'reviewedAt': 1732651869, 'reviewedAutomatic...
# 2  [{'reviewedAt': 1732117789, 'reviewedAutomatic...
# 3  [{'reviewedAt': 1731516188, 'reviewedAutomatic...
# 4  [{'reviewedAt': 1731516092, 'reviewedAutomatic...
#
#                                         customFields  \
# 0  {'Update': {'Automation': 'No', 'Date Made Pub...
# 1  {'Update': {'Automation': 'No', 'Date Made Pub...
# 2  {'Update': {'Automation': 'No', 'Date Made Pub...
# 3  {'Update': {'Automation': 'No', 'Date Made Pub...
# 4  {'Update': {'Automation': 'No', 'Date Made Pub...
#
#                                                 tags
# 0                                               None
# 1                                    [address point]
# 2  [greenhouse gas emissions, greenhouse, fuel, e...
# 3                            [footprints, buildings]
# 4                  [building, footprint, footprints]
#
# [5 rows x 21 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3237 entries, 0 to 3236
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3237 non-null   object
#  1   name               3237 non-null   object
#  2   attribution        3170 non-null   object
#  3   attributionLink    449 non-null    object
#  4   category           3137 non-null   object
#  5   createdAt          3237 non-null   object
#  6   dataUpdatedAt      3060 non-null   object
#  7   dataUri            3237 non-null   object
#  8   description        3172 non-null   object
#  9   domain             3237 non-null   object
#  10  externalId         0 non-null      float64
#  11  hideFromCatalog    3237 non-null   bool
#  12  hideFromDataJson   3237 non-null   bool
#  13  license            79 non-null     object
#  14  metadataUpdatedAt  3237 non-null   object
#  15  provenance         3237 non-null   object
#  16  updatedAt          3237 non-null   object
#  17  webUri             3237 non-null   object
#  18  approvals          3237 non-null   object
#  19  customFields       3235 non-null   object
#  20  tags               2453 non-null   object
# dtypes: bool(2), float64(1), object(18)
# memory usage: 486.9+ KB

# %%
# example of Metadata API for 311 dataset
url = 'https://data.cityofnewyork.us/api/views/metadata/v1/erm2-nwe9/'

# fetch the JSON data from the web
response = requests.get(url)

# parse the JSON response
data_dict = response.json()

# convert to a df
df = pd.DataFrame([data_dict])

# preview data
df.head()
# Out:
#           id                                       name attribution  \
# 0  erm2-nwe9  311 Service Requests from 2010 to Present         311
#
#   attributionLink         category                 createdAt  \
# 0            None  Social Services  2011-10-10T05:52:17+0000
#
#               dataUpdatedAt                                           dataUri  \
# 0  2024-12-03T02:35:30+0000  https://data.cityofnewyork.us/resource/erm2-nwe9
#
#                                          description                 domain  \
# 0  <b>NOTE:</b> The 311 dataset is currently show...  data.cityofnewyork.us
#
#    ... hideFromCatalog  hideFromDataJson  license         metadataUpdatedAt  \
# 0  ...           False             False     None  2024-05-28T20:32:16+0000
#
#   provenance                 updatedAt  \
# 0   OFFICIAL  2024-05-28T20:32:16+0000
#
#                                       webUri  \
# 0  https://data.cityofnewyork.us/d/erm2-nwe9
#
#                                            approvals  \
# 0  [{'reviewedAt': 1524193398, 'reviewedAutomatic...
#
#                                         customFields  \
# 0  {'Update': {'Automation': 'Yes', 'Date Made Pu...
#
#                                                 tags
# 0  [311, 311 service requests, city government, s...
#
# [1 rows x 21 columns]

# %%
# preview columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1 non-null      object
#  1   name               1 non-null      object
#  2   attribution        1 non-null      object
#  3   attributionLink    0 non-null      object
#  4   category           1 non-null      object
#  5   createdAt          1 non-null      object
#  6   dataUpdatedAt      1 non-null      object
#  7   dataUri            1 non-null      object
#  8   description        1 non-null      object
#  9   domain             1 non-null      object
#  10  externalId         0 non-null      object
#  11  hideFromCatalog    1 non-null      bool
#  12  hideFromDataJson   1 non-null      bool
#  13  license            0 non-null      object
#  14  metadataUpdatedAt  1 non-null      object
#  15  provenance         1 non-null      object
#  16  updatedAt          1 non-null      object
#  17  webUri             1 non-null      object
#  18  approvals          1 non-null      object
#  19  customFields       1 non-null      object
#  20  tags               1 non-null      object
# dtypes: bool(2), object(19)
# memory usage: 282.0+ bytes

# %%
# close connection
client.close()
